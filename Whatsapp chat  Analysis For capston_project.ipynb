# %%
pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      -------------------------------------- 421.5/421.5 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Wordcloud
# Out:
# Requirement already satisfied: Wordcloud in d:\python\lib\site-packages (1.9.3)
# Requirement already satisfied: matplotlib in d:\python\lib\site-packages (from Wordcloud) (3.7.0)
# Requirement already satisfied: numpy>=1.6.1 in d:\python\lib\site-packages (from Wordcloud) (1.23.5)
# Requirement already satisfied: pillow in d:\python\lib\site-packages (from Wordcloud) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python\lib\site-packages (from matplotlib->Wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\python\lib\site-packages (from matplotlib->Wordcloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python\lib\site-packages (from matplotlib->Wordcloud) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in d:\python\lib\site-packages (from matplotlib->Wordcloud) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\python\lib\site-packages (from matplotlib->Wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python\lib\site-packages (from matplotlib->Wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python\lib\site-packages (from matplotlib->Wordcloud) (1.4.4)
# Requirement already satisfied: six>=1.5 in d:\python\lib\site-packages (from python-dateutil>=2.7->matplotlib->Wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import regex as re
import pandas as pd
import numpy as np
import emoji
import plotly.express as px
from collections import Counter
import matplotlib.pyplot as plt
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# % matplotlib inline

# %%
pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ------------------------------------ 239.6/239.6 kB 976.0 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in d:\python\lib\site-packages (from python-docx) (4.4.0)
# Requirement already satisfied: lxml>=3.1.0 in d:\python\lib\site-packages (from python-docx) (4.9.1)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

# %%
def startsWithDateAndTime(s):
    pattern = r"[\d]{1,2}/[\d]{1,2}/[\d]{4}" #, r"([0-9]+):([0-9]+)[ ]?(AM|PM|am|pm)? -" # [\d]{1,2}/[\d]{1,2}/[\d]{4} ^([0-9]+)(\/)([0-9]+)(\/)([0-9]+)
    result = re.findall(pattern, s)
    print("result :", result)
    if result:
        return True
    else:
        False

# %%
def FindAuthor(s):
    s=s.split(":")
    if len(s)==2:
        return True
    else:
        return False

# %%
def getDataPoint(line):
    splitLine = line.split(' - ')
    dateTime = splitLine[0]
    date, time = dateTime.split(', ')
    message = ' '.join(splitLine[1:])
    if FindAuthor(message):
        splitMessage = message.split(': ')
        author = splitMessage[0]
        message = ' '.join(splitMessage[1:])
    else:
        author = None
    return date, time, author, message

# %%
pip install google.colab
# Out:
# Collecting google.colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      -------------------------------------- 72.9/72.9 kB 994.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-auth~=1.4.0
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.2/64.2 kB 1.1 MB/s eta 0:00:00
# Collecting ipykernel~=4.6.0
#   Downloading ipykernel-4.6.1-py3-none-any.whl (104 kB)
#      -------------------------------------- 104.5/104.5 kB 1.0 MB/s eta 0:00:00
# Collecting ipython~=5.5.0
#   Downloading ipython-5.5.0-py3-none-any.whl (758 kB)
#      -------------------------------------- 758.9/758.9 kB 1.1 MB/s eta 0:00:00
# Collecting notebook~=5.2.0
#   Downloading notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
#      ---------------------------------------- 8.0/8.0 MB 1.9 MB/s eta 0:00:00
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas~=0.24.0
#   Downloading pandas-0.24.2.tar.gz (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting portpicker~=1.2.0
#   Downloading portpicker-1.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting requests~=2.21.0
#   Downloading requests-2.21.0-py2.py3-none-any.whl (57 kB)
#      ---------------------------------------- 58.0/58.0 kB 3.2 MB/s eta 0:00:00
# Collecting tornado~=4.5.0
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      -------------------------------------- 484.2/484.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\python\lib\site-packages (from google-auth~=1.4.0->google.colab) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in d:\python\lib\site-packages (from google-auth~=1.4.0->google.colab) (4.9)
# Requirement already satisfied: cachetools>=2.0.0 in d:\python\lib\site-packages (from google-auth~=1.4.0->google.colab) (5.3.2)
# Requirement already satisfied: traitlets>=4.1.0 in d:\python\lib\site-packages (from ipykernel~=4.6.0->google.colab) (5.7.1)
# Requirement already satisfied: jupyter-client in d:\python\lib\site-packages (from ipykernel~=4.6.0->google.colab) (7.3.4)
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Downloading prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
#      -------------------------------------- 245.4/245.4 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\python\lib\site-packages (from ipython~=5.5.0->google.colab) (0.4.6)
# Collecting simplegeneric>0.8
#   Downloading simplegeneric-0.8.1.zip (12 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pickleshare in d:\python\lib\site-packages (from ipython~=5.5.0->google.colab) (0.7.5)
# Requirement already satisfied: decorator in d:\python\lib\site-packages (from ipython~=5.5.0->google.colab) (5.1.1)
# Requirement already satisfied: pygments in d:\python\lib\site-packages (from ipython~=5.5.0->google.colab) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in d:\python\lib\site-packages (from ipython~=5.5.0->google.colab) (65.6.3)
# Requirement already satisfied: nbconvert in d:\python\lib\site-packages (from notebook~=5.2.0->google.colab) (6.5.4)
# Requirement already satisfied: nbformat in d:\python\lib\site-packages (from notebook~=5.2.0->google.colab) (5.7.0)
# Requirement already satisfied: jupyter-core in d:\python\lib\site-packages (from notebook~=5.2.0->google.colab) (5.2.0)
# Requirement already satisfied: jinja2 in d:\python\lib\site-packages (from notebook~=5.2.0->google.colab) (3.1.2)
# Requirement already satisfied: ipython-genutils in d:\python\lib\site-packages (from notebook~=5.2.0->google.colab) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in d:\python\lib\site-packages (from pandas~=0.24.0->google.colab) (2.8.2)
# Requirement already satisfied: pytz>=2011k in d:\python\lib\site-packages (from pandas~=0.24.0->google.colab) (2022.7)
# Requirement already satisfied: numpy>=1.12.0 in d:\python\lib\site-packages (from pandas~=0.24.0->google.colab) (1.23.5)
# Collecting urllib3<1.25,>=1.21.1
#   Downloading urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
#      -------------------------------------- 118.8/118.8 kB 2.3 MB/s eta 0:00:00
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      -------------------------------------- 133.4/133.4 kB 2.6 MB/s eta 0:00:00
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.6/58.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in d:\python\lib\site-packages (from requests~=2.21.0->google.colab) (2022.12.7)
# Requirement already satisfied: wcwidth in d:\python\lib\site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google.colab) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\python\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=1.4.0->google.colab) (0.4.8)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\python\lib\site-packages (from jinja2->notebook~=5.2.0->google.colab) (2.1.1)
# Requirement already satisfied: pyzmq>=23.0 in d:\python\lib\site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (23.2.0)
# Collecting jupyter-client
#   Downloading jupyter_client-8.6.0-py3-none-any.whl (105 kB)
#      -------------------------------------- 105.9/105.9 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.4.0-py3-none-any.whl (103 kB)
#      -------------------------------------- 104.0/104.0 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.3.1-py3-none-any.whl (104 kB)
#      -------------------------------------- 104.1/104.1 kB 3.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.2/103.2 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.2.0-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.2/103.2 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.1.0-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.9/102.9 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.0.3-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.7/102.7 kB 3.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.0.2-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.3/103.3 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-8.0.1-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.2/103.2 kB 1.5 MB/s eta 0:00:00
#   Downloading jupyter_client-8.0.0-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.2/103.2 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.5/133.5 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in d:\python\lib\site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in d:\python\lib\site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (1.5.6)
#   Downloading jupyter_client-7.4.8-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.5/133.5 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.7-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.5/133.5 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.6-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.5/133.5 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.5-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.3/132.3 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.4-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.3/132.3 kB 1.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.3-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.2/132.2 kB 1.3 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.2-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.2/132.2 kB 2.6 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.1-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.1/132.1 kB 2.6 MB/s eta 0:00:00
#   Downloading jupyter_client-7.4.0-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.2/132.2 kB 2.0 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.5-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.1/132.1 kB 2.6 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.3-py3-none-any.whl (131 kB)
#      ------------------------------------ 132.0/132.0 kB 973.9 kB/s eta 0:00:00
#   Downloading jupyter_client-7.3.2-py3-none-any.whl (131 kB)
#      -------------------------------------- 131.9/131.9 kB 2.6 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.1-py3-none-any.whl (130 kB)
#      -------------------------------------- 131.0/131.0 kB 1.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.3.0-py3-none-any.whl (130 kB)
#      -------------------------------------- 130.9/130.9 kB 1.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.2-py3-none-any.whl (130 kB)
#      -------------------------------------- 130.6/130.6 kB 1.9 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.1-py3-none-any.whl (130 kB)
#      -------------------------------------- 130.4/130.4 kB 1.3 MB/s eta 0:00:00
#   Downloading jupyter_client-7.2.0-py3-none-any.whl (130 kB)
#      -------------------------------------- 130.5/130.5 kB 1.5 MB/s eta 0:00:00
#   Downloading jupyter_client-7.1.2-py3-none-any.whl (130 kB)
#      -------------------------------------- 130.3/130.3 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in d:\python\lib\site-packages (from jupyter-core->notebook~=5.2.0->google.colab) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in d:\python\lib\site-packages (from jupyter-core->notebook~=5.2.0->google.colab) (305.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.5.13)
# Requirement already satisfied: defusedxml in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.7.1)
# Requirement already satisfied: packaging in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (22.0)
# Requirement already satisfied: beautifulsoup4 in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (4.11.1)
# Requirement already satisfied: tinycss2 in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.2.1)
# Requirement already satisfied: bleach in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.8.4)
# Requirement already satisfied: lxml in d:\python\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (4.9.1)
# Requirement already satisfied: jsonschema>=2.6 in d:\python\lib\site-packages (from nbformat->notebook~=5.2.0->google.colab) (4.17.3)
# Requirement already satisfied: fastjsonschema in d:\python\lib\site-packages (from nbformat->notebook~=5.2.0->google.colab) (2.16.2)
# Requirement already satisfied: attrs>=17.4.0 in d:\python\lib\site-packages (from jsonschema>=2.6->nbformat->notebook~=5.2.0->google.colab) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\python\lib\site-packages (from jsonschema>=2.6->nbformat->notebook~=5.2.0->google.colab) (0.18.0)
# Requirement already satisfied: soupsieve>1.2 in d:\python\lib\site-packages (from beautifulsoup4->nbconvert->notebook~=5.2.0->google.colab) (2.3.2.post1)
# Requirement already satisfied: webencodings in d:\python\lib\site-packages (from bleach->nbconvert->notebook~=5.2.0->google.colab) (0.5.1)
# Building wheels for collected packages: google.colab, pandas, portpicker, tornado, simplegeneric
#   Building wheel for google.colab (setup.py): started
#   Building wheel for google.colab (setup.py): finished with status 'done'
#   Created wheel for google.colab: filename=google_colab-1.0.0-py2.py3-none-any.whl size=102291 sha256=08b451521ea00f8a2615374584f45065da9dd4b0df2dde5aadfd257def6832c3
#   Stored in directory: c:\users\tapas\appdata\local\pip\cache\wheels\a7\94\43\7901bf33a9ed027087272a7bca82ce8c72a3ff010848008ea2
#   Building wheel for pandas (setup.py): started
#   Building wheel for pandas (setup.py): finished with status 'error'
#   Running setup.py clean for pandas
#   Building wheel for portpicker (setup.py): started
#   Building wheel for portpicker (setup.py): finished with status 'done'
#   Created wheel for portpicker: filename=portpicker-1.2.0-py3-none-any.whl size=13423 sha256=74720e754555ff4c31ab48b5870d936e38b4ee21a0b3baf4655ae81954d0e074
#   Stored in directory: c:\users\tapas\appdata\local\pip\cache\wheels\b9\78\1b\48ea4ac434014227813c657967ac5ca8e4c43adde9d5746ddc
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-4.5.3-cp310-cp310-win_amd64.whl size=420793 sha256=854cd2bda61ade0ea38223c0f8fb41a718f1c7f1218ec68e20e109169811d6c3
#   Stored in directory: c:\users\tapas\appdata\local\pip\cache\wheels\ab\d9\2c\94268c13f7499fca26d9d4997e7279ba835a5d5ec2f327c2a5
#   Building wheel for simplegeneric (setup.py): started
#   Building wheel for simplegeneric (setup.py): finished with status 'done'
#   Created wheel for simplegeneric: filename=simplegeneric-0.8.1-py3-none-any.whl size=5099 sha256=fa70ac46d1024ce648c3d598adc76a280dd9d8eba2e36566f6dac337690ae66c
#   Stored in directory: c:\users\tapas\appdata\local\pip\cache\wheels\8b\3e\a5\4ff6108430b11ef9db12964f42d3ce104ca6a85de70c49bf21
# Successfully built google.colab portpicker tornado simplegeneric
# Failed to build pandas
# Installing collected packages: tornado, simplegeneric, portpicker, chardet, urllib3, six, idna, requests, prompt-toolkit, google-auth, pandas, jupyter-client, ipython, ipykernel, notebook, google.colab
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.14
#     Uninstalling urllib3-1.26.14:
#       Successfully uninstalled urllib3-1.26.14
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.36
#     Uninstalling prompt-toolkit-3.0.36:
#       Successfully uninstalled prompt-toolkit-3.0.36
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.23.4
#     Uninstalling google-auth-2.23.4:
#       Successfully uninstalled google-auth-2.23.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Running setup.py install for pandas: started
#   Running setup.py install for pandas: finished with status 'error'
#   Rolling back uninstall of pandas
#   Moving to d:\python\lib\site-packages\pandas-1.5.3.dist-info\
#    from D:\python\Lib\site-packages\~andas-1.5.3.dist-info
#   Moving to d:\python\lib\site-packages\pandas\
#    from D:\python\Lib\site-packages\~andas
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [841 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\pandas
#   copying pandas\conftest.py -> build\lib.win-amd64-cpython-310\pandas
#   copying pandas\testing.py -> build\lib.win-amd64-cpython-310\pandas
#   copying pandas\_version.py -> build\lib.win-amd64-cpython-310\pandas
#   copying pandas\__init__.py -> build\lib.win-amd64-cpython-310\pandas
#   creating build\lib.win-amd64-cpython-310\pandas\api
#   copying pandas\api\__init__.py -> build\lib.win-amd64-cpython-310\pandas\api
#   creating build\lib.win-amd64-cpython-310\pandas\arrays
#   copying pandas\arrays\__init__.py -> build\lib.win-amd64-cpython-310\pandas\arrays
#   creating build\lib.win-amd64-cpython-310\pandas\compat
#   copying pandas\compat\chainmap.py -> build\lib.win-amd64-cpython-310\pandas\compat
#   copying pandas\compat\chainmap_impl.py -> build\lib.win-amd64-cpython-310\pandas\compat
#   copying pandas\compat\pickle_compat.py -> build\lib.win-amd64-cpython-310\pandas\compat
#   copying pandas\compat\__init__.py -> build\lib.win-amd64-cpython-310\pandas\compat
#   creating build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\accessor.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\algorithms.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\api.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\apply.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\base.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\categorical.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\common.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\config.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\config_init.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\frame.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\generic.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\index.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\indexing.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\missing.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\nanops.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\ops.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\panel.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\resample.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\series.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\sorting.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\strings.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\window.py -> build\lib.win-amd64-cpython-310\pandas\core
#   copying pandas\core\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core
#   creating build\lib.win-amd64-cpython-310\pandas\errors
#   copying pandas\errors\__init__.py -> build\lib.win-amd64-cpython-310\pandas\errors
#   creating build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\api.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\clipboards.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\common.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\date_converters.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\excel.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\feather_format.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\gbq.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\gcs.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\html.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\packers.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\parquet.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\parsers.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\pickle.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\pytables.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\s3.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\sql.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\stata.py -> build\lib.win-amd64-cpython-310\pandas\io
#   copying pandas\io\__init__.py -> build\lib.win-amd64-cpython-310\pandas\io
#   creating build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\_compat.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\_converter.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\_core.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\_misc.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\_style.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\_timeseries.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\_tools.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   copying pandas\plotting\__init__.py -> build\lib.win-amd64-cpython-310\pandas\plotting
#   creating build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_algos.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_base.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_common.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_compat.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_config.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_downstream.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_errors.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_expressions.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_join.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_lib.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_multilevel.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_nanops.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_panel.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_register_accessor.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_sorting.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_strings.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_take.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\test_window.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   copying pandas\tests\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests
#   creating build\lib.win-amd64-cpython-310\pandas\tseries
#   copying pandas\tseries\api.py -> build\lib.win-amd64-cpython-310\pandas\tseries
#   copying pandas\tseries\converter.py -> build\lib.win-amd64-cpython-310\pandas\tseries
#   copying pandas\tseries\frequencies.py -> build\lib.win-amd64-cpython-310\pandas\tseries
#   copying pandas\tseries\holiday.py -> build\lib.win-amd64-cpython-310\pandas\tseries
#   copying pandas\tseries\offsets.py -> build\lib.win-amd64-cpython-310\pandas\tseries
#   copying pandas\tseries\plotting.py -> build\lib.win-amd64-cpython-310\pandas\tseries
#   copying pandas\tseries\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tseries
#   creating build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\testing.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_decorators.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_depr_module.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_doctools.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_exceptions.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_print_versions.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_tester.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_test_decorators.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\_validators.py -> build\lib.win-amd64-cpython-310\pandas\util
#   copying pandas\util\__init__.py -> build\lib.win-amd64-cpython-310\pandas\util
#   creating build\lib.win-amd64-cpython-310\pandas\_libs
#   copying pandas\_libs\__init__.py -> build\lib.win-amd64-cpython-310\pandas\_libs
#   creating build\lib.win-amd64-cpython-310\pandas\api\extensions
#   copying pandas\api\extensions\__init__.py -> build\lib.win-amd64-cpython-310\pandas\api\extensions
#   creating build\lib.win-amd64-cpython-310\pandas\api\types
#   copying pandas\api\types\__init__.py -> build\lib.win-amd64-cpython-310\pandas\api\types
#   creating build\lib.win-amd64-cpython-310\pandas\compat\numpy
#   copying pandas\compat\numpy\function.py -> build\lib.win-amd64-cpython-310\pandas\compat\numpy
#   copying pandas\compat\numpy\__init__.py -> build\lib.win-amd64-cpython-310\pandas\compat\numpy
#   creating build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\array_.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\base.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\categorical.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\datetimelike.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\datetimes.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\integer.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\interval.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\numpy_.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\period.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\sparse.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\timedeltas.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\_ranges.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   copying pandas\core\arrays\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\arrays
#   creating build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\align.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\api.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\check.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\common.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\engines.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\eval.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\expr.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\expressions.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\ops.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\pytables.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\scope.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   copying pandas\core\computation\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\computation
#   creating build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\api.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\base.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\cast.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\common.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\concat.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\dtypes.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\generic.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\inference.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\missing.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   copying pandas\core\dtypes\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\dtypes
#   creating build\lib.win-amd64-cpython-310\pandas\core\groupby
#   copying pandas\core\groupby\base.py -> build\lib.win-amd64-cpython-310\pandas\core\groupby
#   copying pandas\core\groupby\categorical.py -> build\lib.win-amd64-cpython-310\pandas\core\groupby
#   copying pandas\core\groupby\generic.py -> build\lib.win-amd64-cpython-310\pandas\core\groupby
#   copying pandas\core\groupby\groupby.py -> build\lib.win-amd64-cpython-310\pandas\core\groupby
#   copying pandas\core\groupby\grouper.py -> build\lib.win-amd64-cpython-310\pandas\core\groupby
#   copying pandas\core\groupby\ops.py -> build\lib.win-amd64-cpython-310\pandas\core\groupby
#   copying pandas\core\groupby\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\groupby
#   creating build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\accessors.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\api.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\base.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\category.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\datetimelike.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\datetimes.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\frozen.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\interval.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\multi.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\numeric.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\period.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\range.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\timedeltas.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   copying pandas\core\indexes\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\indexes
#   creating build\lib.win-amd64-cpython-310\pandas\core\internals
#   copying pandas\core\internals\arrays.py -> build\lib.win-amd64-cpython-310\pandas\core\internals
#   copying pandas\core\internals\blocks.py -> build\lib.win-amd64-cpython-310\pandas\core\internals
#   copying pandas\core\internals\concat.py -> build\lib.win-amd64-cpython-310\pandas\core\internals
#   copying pandas\core\internals\construction.py -> build\lib.win-amd64-cpython-310\pandas\core\internals
#   copying pandas\core\internals\managers.py -> build\lib.win-amd64-cpython-310\pandas\core\internals
#   copying pandas\core\internals\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\internals
#   creating build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\api.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\concat.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\melt.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\merge.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\pivot.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\reshape.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\tile.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\util.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   copying pandas\core\reshape\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\reshape
#   creating build\lib.win-amd64-cpython-310\pandas\core\sparse
#   copying pandas\core\sparse\api.py -> build\lib.win-amd64-cpython-310\pandas\core\sparse
#   copying pandas\core\sparse\frame.py -> build\lib.win-amd64-cpython-310\pandas\core\sparse
#   copying pandas\core\sparse\scipy_sparse.py -> build\lib.win-amd64-cpython-310\pandas\core\sparse
#   copying pandas\core\sparse\series.py -> build\lib.win-amd64-cpython-310\pandas\core\sparse
#   copying pandas\core\sparse\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\sparse
#   creating build\lib.win-amd64-cpython-310\pandas\core\tools
#   copying pandas\core\tools\datetimes.py -> build\lib.win-amd64-cpython-310\pandas\core\tools
#   copying pandas\core\tools\numeric.py -> build\lib.win-amd64-cpython-310\pandas\core\tools
#   copying pandas\core\tools\timedeltas.py -> build\lib.win-amd64-cpython-310\pandas\core\tools
#   copying pandas\core\tools\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\tools
#   creating build\lib.win-amd64-cpython-310\pandas\core\util
#   copying pandas\core\util\hashing.py -> build\lib.win-amd64-cpython-310\pandas\core\util
#   copying pandas\core\util\__init__.py -> build\lib.win-amd64-cpython-310\pandas\core\util
#   creating build\lib.win-amd64-cpython-310\pandas\io\clipboard
#   copying pandas\io\clipboard\clipboards.py -> build\lib.win-amd64-cpython-310\pandas\io\clipboard
#   copying pandas\io\clipboard\exceptions.py -> build\lib.win-amd64-cpython-310\pandas\io\clipboard
#   copying pandas\io\clipboard\windows.py -> build\lib.win-amd64-cpython-310\pandas\io\clipboard
#   copying pandas\io\clipboard\__init__.py -> build\lib.win-amd64-cpython-310\pandas\io\clipboard
#   creating build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\console.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\css.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\csvs.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\excel.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\format.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\html.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\latex.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\printing.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\style.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\terminal.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   copying pandas\io\formats\__init__.py -> build\lib.win-amd64-cpython-310\pandas\io\formats
#   creating build\lib.win-amd64-cpython-310\pandas\io\json
#   copying pandas\io\json\json.py -> build\lib.win-amd64-cpython-310\pandas\io\json
#   copying pandas\io\json\normalize.py -> build\lib.win-amd64-cpython-310\pandas\io\json
#   copying pandas\io\json\table_schema.py -> build\lib.win-amd64-cpython-310\pandas\io\json
#   copying pandas\io\json\__init__.py -> build\lib.win-amd64-cpython-310\pandas\io\json
#   creating build\lib.win-amd64-cpython-310\pandas\io\msgpack
#   copying pandas\io\msgpack\exceptions.py -> build\lib.win-amd64-cpython-310\pandas\io\msgpack
#   copying pandas\io\msgpack\_version.py -> build\lib.win-amd64-cpython-310\pandas\io\msgpack
#   copying pandas\io\msgpack\__init__.py -> build\lib.win-amd64-cpython-310\pandas\io\msgpack
#   creating build\lib.win-amd64-cpython-310\pandas\io\sas
#   copying pandas\io\sas\sas7bdat.py -> build\lib.win-amd64-cpython-310\pandas\io\sas
#   copying pandas\io\sas\sasreader.py -> build\lib.win-amd64-cpython-310\pandas\io\sas
#   copying pandas\io\sas\sas_constants.py -> build\lib.win-amd64-cpython-310\pandas\io\sas
#   copying pandas\io\sas\sas_xport.py -> build\lib.win-amd64-cpython-310\pandas\io\sas
#   copying pandas\io\sas\__init__.py -> build\lib.win-amd64-cpython-310\pandas\io\sas
#   creating build\lib.win-amd64-cpython-310\pandas\tests\api
#   copying pandas\tests\api\test_api.py -> build\lib.win-amd64-cpython-310\pandas\tests\api
#   copying pandas\tests\api\test_types.py -> build\lib.win-amd64-cpython-310\pandas\tests\api
#   copying pandas\tests\api\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\api
#   creating build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_datetime64.py -> build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_numeric.py -> build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_object.py -> build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_period.py -> build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_timedelta64.py -> build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\arithmetic
#   creating build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\test_array.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\test_datetimelike.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\test_datetimes.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\test_integer.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\test_numpy.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\test_period.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\test_timedeltas.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   copying pandas\tests\arrays\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\arrays
#   creating build\lib.win-amd64-cpython-310\pandas\tests\computation
#   copying pandas\tests\computation\test_compat.py -> build\lib.win-amd64-cpython-310\pandas\tests\computation
#   copying pandas\tests\computation\test_eval.py -> build\lib.win-amd64-cpython-310\pandas\tests\computation
#   copying pandas\tests\computation\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\computation
#   creating build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_common.py -> build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_concat.py -> build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_dtypes.py -> build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_generic.py -> build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_inference.py -> build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_missing.py -> build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   copying pandas\tests\dtypes\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\dtypes
#   creating build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_categorical.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_common.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_datetime.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_external_block.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_integer.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_interval.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_period.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\test_sparse.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   copying pandas\tests\extension\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\extension
#   creating build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\common.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_alter_axes.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_analytics.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_api.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_apply.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_arithmetic.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_asof.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_axis_select_reindex.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_block_internals.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_combine_concat.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_constructors.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_convert_to.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_dtypes.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_duplicates.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_indexing.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_join.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_missing.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_mutate_columns.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_nonunique_indexes.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_operators.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_period.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_quantile.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_query_eval.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_rank.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_replace.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_repr_info.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_reshape.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_sorting.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_sort_values_level_as_str.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_subclass.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_timeseries.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_timezones.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_to_csv.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\test_validate.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   copying pandas\tests\frame\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\frame
#   creating build\lib.win-amd64-cpython-310\pandas\tests\generic
#   copying pandas\tests\generic\test_frame.py -> build\lib.win-amd64-cpython-310\pandas\tests\generic
#   copying pandas\tests\generic\test_generic.py -> build\lib.win-amd64-cpython-310\pandas\tests\generic
#   copying pandas\tests\generic\test_label_or_level_utils.py -> build\lib.win-amd64-cpython-310\pandas\tests\generic
#   copying pandas\tests\generic\test_panel.py -> build\lib.win-amd64-cpython-310\pandas\tests\generic
#   copying pandas\tests\generic\test_series.py -> build\lib.win-amd64-cpython-310\pandas\tests\generic
#   copying pandas\tests\generic\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\generic
#   creating build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_apply.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_bin_groupby.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_categorical.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_counting.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_filters.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_function.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_groupby.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_grouping.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_index_as_string.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_nth.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_rank.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_timegrouper.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_transform.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_value_counts.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\test_whitelist.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   copying pandas\tests\groupby\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\groupby
#   creating build\lib.win-amd64-cpython-310\pandas\tests\indexes
#   copying pandas\tests\indexes\common.py -> build\lib.win-amd64-cpython-310\pandas\tests\indexes
# ...
#   copying pandas\tests\io\json\test_ujson.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\json
#   copying pandas\tests\io\json\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\json
#   creating build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\common.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_buffer.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_case.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_except.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_extension.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_format.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_limits.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_newspec.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_obj.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_pack.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_read_size.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_seq.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_sequnpack.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_subtype.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_unpack.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\test_unpack_raw.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   copying pandas\tests\io\msgpack\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\msgpack
#   creating build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_comment.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_common.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_compression.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_converters.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_c_parser_only.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_dialect.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_dtypes.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_header.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_index_col.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_mangle_dupes.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_multi_thread.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_na_values.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_network.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_parse_dates.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_python_parser_only.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_quoting.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_read_fwf.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_skiprows.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_textreader.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_unsupported.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\test_usecols.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   copying pandas\tests\io\parser\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\parser
#   creating build\lib.win-amd64-cpython-310\pandas\tests\io\sas
#   copying pandas\tests\io\sas\test_sas.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\sas
#   copying pandas\tests\io\sas\test_sas7bdat.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\sas
#   copying pandas\tests\io\sas\test_xport.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\sas
#   copying pandas\tests\io\sas\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\io\sas
#   creating build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   copying pandas\tests\reshape\merge\test_join.py -> build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   copying pandas\tests\reshape\merge\test_merge.py -> build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   copying pandas\tests\reshape\merge\test_merge_asof.py -> build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   copying pandas\tests\reshape\merge\test_merge_index_as_string.py -> build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   copying pandas\tests\reshape\merge\test_merge_ordered.py -> build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   copying pandas\tests\reshape\merge\test_multi.py -> build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   copying pandas\tests\reshape\merge\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\reshape\merge
#   creating build\lib.win-amd64-cpython-310\pandas\tests\scalar\interval
#   copying pandas\tests\scalar\interval\test_interval.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\interval
#   copying pandas\tests\scalar\interval\test_ops.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\interval
#   copying pandas\tests\scalar\interval\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\interval
#   creating build\lib.win-amd64-cpython-310\pandas\tests\scalar\period
#   copying pandas\tests\scalar\period\test_asfreq.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\period
#   copying pandas\tests\scalar\period\test_period.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\period
#   copying pandas\tests\scalar\period\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\period
#   creating build\lib.win-amd64-cpython-310\pandas\tests\scalar\timedelta
#   copying pandas\tests\scalar\timedelta\test_arithmetic.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timedelta
#   copying pandas\tests\scalar\timedelta\test_construction.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timedelta
#   copying pandas\tests\scalar\timedelta\test_formats.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timedelta
#   copying pandas\tests\scalar\timedelta\test_timedelta.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timedelta
#   copying pandas\tests\scalar\timedelta\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timedelta
#   creating build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   copying pandas\tests\scalar\timestamp\test_arithmetic.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   copying pandas\tests\scalar\timestamp\test_comparisons.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   copying pandas\tests\scalar\timestamp\test_rendering.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   copying pandas\tests\scalar\timestamp\test_timestamp.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   copying pandas\tests\scalar\timestamp\test_timezones.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   copying pandas\tests\scalar\timestamp\test_unary_ops.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   copying pandas\tests\scalar\timestamp\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\scalar\timestamp
#   creating build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_alter_index.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_boolean.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_callable.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_datetime.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_iloc.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_indexing.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_loc.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\test_numeric.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   copying pandas\tests\series\indexing\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\series\indexing
#   creating build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\test_analytics.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\test_apply.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\test_frame.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\test_indexing.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\test_to_csv.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\test_to_from_scipy.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   copying pandas\tests\sparse\frame\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\frame
#   creating build\lib.win-amd64-cpython-310\pandas\tests\sparse\series
#   copying pandas\tests\sparse\series\test_indexing.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\series
#   copying pandas\tests\sparse\series\test_series.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\series
#   copying pandas\tests\sparse\series\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\sparse\series
#   creating build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\common.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\conftest.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\test_fiscal.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\test_offsets.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\test_offsets_properties.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\test_ticks.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\test_yqm_offsets.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   copying pandas\tests\tseries\offsets\__init__.py -> build\lib.win-amd64-cpython-310\pandas\tests\tseries\offsets
#   creating build\lib.win-amd64-cpython-310\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\__init__.py -> build\lib.win-amd64-cpython-310\pandas\_libs\tslibs
#   creating build\lib.win-amd64-cpython-310\pandas\io\formats\templates
#   copying pandas\io\formats\templates\html.tpl -> build\lib.win-amd64-cpython-310\pandas\io\formats\templates
#   UPDATING build\lib.win-amd64-cpython-310\pandas/_version.py
#   set build\lib.win-amd64-cpython-310\pandas/_version.py to '0.24.2'
#   running build_ext
#   pandas._libs.algos: -> [['pandas\\_libs/algos.c']]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\tapas\AppData\Local\Temp\pip-install-ufadtqqr\pandas_6746ba776db14acd85004aff047b5a29\setup.py", line 730, in <module>
#       setup(name=DISTNAME,
#     File "D:\python\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\python\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "D:\python\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "D:\python\lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "D:\python\lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "D:\python\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\python\lib\site-packages\setuptools\command\install.py", line 68, in run
#       return orig.install.run(self)
#     File "D:\python\lib\site-packages\setuptools\_distutils\command\install.py", line 698, in run
#       self.run_command('build')
#     File "D:\python\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "D:\python\lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "D:\python\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\python\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "D:\python\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "D:\python\lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "D:\python\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\python\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 346, in run
#       self.build_extensions()
#     File "C:\Users\tapas\AppData\Local\Temp\pip-install-ufadtqqr\pandas_6746ba776db14acd85004aff047b5a29\setup.py", line 372, in build_extensions
#       self.check_cython_extensions(self.extensions)
#     File "C:\Users\tapas\AppData\Local\Temp\pip-install-ufadtqqr\pandas_6746ba776db14acd85004aff047b5a29\setup.py", line 366, in check_cython_extensions
#       raise Exception("""Cython-generated file '{src}' not found.
#   Exception: Cython-generated file 'pandas\_libs/algos.c' not found.
#                   Cython is required to compile pandas from a development branch.
#                   Please install Cython or download a release package of pandas.
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# pandas
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# uploaded = files.upload()
parsedData = [] # List to keep track of data so it can be used by a Pandas dataframe
conversation = (r"C:/Users/tapas/Downloads/whatsappchatwithpresentsadhanagroup/WhatsApp Chat with Present Sadhana group.txt")# path for the whatsapp text file
with open(conversation, encoding="utf-8-sig") as fp:

    fp.readline() 
    print("fp.readline() : \n", fp.readline())
    messageBuffer = []
    print("messageBuffer : \n", messageBuffer)
    date, time, author = None, None, None
    while True:
        line = fp.readline()
        if not line:
            break
        line = line.strip()
        print("line: \n", line)
        if startsWithDateAndTime(line):
            print("startsWithDateAndTime : \n", startsWithDateAndTime)
            if len(messageBuffer) > 0:
                parsedData.append([date, time, author, ' '.join(messageBuffer)])
                messageBuffer.clear()
                date, time, author, message = getDataPoint(line)
                messageBuffer.append(message)

        else:
            messageBuffer.append(line)
# Out:
# fp.readline() :
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0014.jpg (file attached)
#
# messageBuffer :
#  []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0013.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0012.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0011.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0005.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0010.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0008.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0009.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0007.jpg (file attached)
# result : []
# line:
#  15/08/23, 10:52 am - Susovan (Mess: IMG-20230815-WA0006.jpg (file attached)
# result : []
# line:
#  15/08/23, 7:34 pm - Lob: IMG-20230815-WA0031.jpg (file attached)
# result : []
# line:
#  16/08/23, 6:31 am - +91 76027 79174: Mill on hbe Niru Mandi 🙏👍
# result : []
# line:
#  16/08/23, 1:41 pm - Subhankar(mess: Meal hobe
# result : []
# line:
#  Subhankar
# result : []
# line:
#  16/08/23, 5:53 pm - +91 76027 79174: Mill off hbe sudu ratre bela ta ....kal sokal bela hbe ....Niru Mandi 🙏👍
# result : []
# line:
#  17/08/23, 1:35 pm - Sandip Maity Mess Sadhana: @919775294089
# result : []
# line:
#  Dear Manager
# result : []
# line:
#  My meal will continue from tonight......
# result : []
# line:
#  *Sandip*
# result : []
# line:
#  17/08/23, 5:15 pm - +91 76027 79174: Sudu rate mil off hbe Niru Mandi..🙏👍
# result : []
# line:
#  17/08/23, 6:04 pm - +91 80012 92291: <Media omitted>
# result : []
# line:
#  18/08/23, 11:16 pm - Tapas Pradhan: Kal sokal thake meal off thakbe
# result : []
# line:
#  18/08/23, 11:40 pm - Subhankar(mess: Kal sakale meal off thakbe
# result : []
# line:
#  18/08/23, 11:40 pm - Subhankar(mess: Subhankar
# result : []
# line:
#  18/08/23, 11:41 pm - Sandip Maity Mess Sadhana: Kal sokale Meal off thakbe
# result : []
# line:
#  Sandip
# result : []
# line:
#  18/08/23, 11:48 pm - Purna(mess-mid: Sudhu Kal sokale meal off... Purna.
# result : []
# line:
#  19/08/23, 10:54 pm - Tapas Pradhan: Kal sokale meal hobe
# result : []
# line:
#  19/08/23, 11:18 pm - Susovan (Mess: Kall sokal a meal hobe susovan
# result : []
# line:
#  20/08/23, 5:46 pm - Saikat: Sudhu rate meal off
# result : []
# line:
#  sokal e meal hobe
# result : []
# line:
#  (saikat)
# result : []
# line:
#  20/08/23, 5:52 pm - JOYPRAKASH MAHATA: Ratay meal off thakbey
# result : []
# line:
#  20/08/23, 6:25 pm - Tapas Pradhan: Sudhu rate meal off thakbe
# result : []
# line:
#  sokal e meal hobe
# result : []
# line:
#  21/08/23, 10:23 am - Soumitra (Mid Mess: <Media omitted>
# result : []
# line:
#  please take one piece
# result : []
# line:
#  22/08/23, 4:29 pm - +91 76027 79174: Rate guest mil hbe ...Niru Mandi 🙏👍
# result : []
# line:
#  22/08/23, 5:38 pm - JOYPRAKASH MAHATA: Ratay meal hobay
# result : []
# line:
#  23/08/23, 6:20 am - +91 76027 79174: Ekhno hbe ekta guest mil 👍🙏
# result : []
# line:
#  23/08/23, 3:29 pm - Ranjit Mess Sadhana: This message was deleted
# result : []
# line:
#  23/08/23, 4:18 pm - Tapas Pradhan: Rate Ekta guest meal hobe
# result : []
# line:
#  24/08/23, 5:59 pm - Tapas Pradhan: Rate meal off thakbe,
# result : []
# line:
#  Kal sokale hobe
# result : []
# line:
#  26/08/23, 9:25 am - +91 76027 79174: *একটা বিশেষ বিজ্ঞপ্তি*
# result : []
# line:
#  Economics subject এর... ক্লাস -11পড়ে (English Medium).... .... কেউ যদি টিউশন পড়াতে চাও জলদি জানা বে 🙏👍
# result : []
# line:
#  26/08/23, 9:49 am - Susovan (Mess: Online hole hobe
# result : []
# line:
#  26/08/23, 2:51 pm - Monisankar Pradhan Mess: রাত থেকে আমার মিল চালু হবে- মনিশংকর
# result : []
# line:
#  26/08/23, 10:37 pm - +91 76027 79174: Kal k sudu sokal bela mil off tak be...Niru Mandi 🙏👍
# result : []
# line:
#  30/08/23, 1:37 pm - Sasti: Aj rat thaka amr meal chalu hoba (sosthi)
# result : []
# line:
#  30/08/23, 2:24 pm - +91 99335 77215: রাতে আমার মিল হবে.... প্রসেনজিৎ
# result : []
# line:
#  30/08/23, 4:22 pm - Susovan (Mess: https://amazon.in@wp-link.ru/HveyOjQz/?free-returned-products-from-amazon.html
# result : []
# line:
#  30/08/23, 5:04 pm - +91 82509 91152: This message was deleted
# result : []
# line:
#  30/08/23, 5:05 pm - +91 82509 91152: <Media omitted>
# result : []
# line:
#  30/08/23, 5:06 pm - +91 82509 91152: IMG-20230830-WA0007.jpg (file attached)
# result : []
# line:
#  30/08/23, 9:57 pm - Ranjit Mess Sadhana: Happy birthday to you Soumitra da
# result : []
# line:
#  30/08/23, 10:57 pm - Sandip Maity Mess Sadhana: Kal sokal theke amar meal continue on hobe
# result : []
# line:
#  *Sandip*
# result : []
# line:
#  31/08/23, 10:20 am - +91 832 874 4399: Ratre theke amar meal on hobe ... Subhadip
# result : []
# line:
#  31/08/23, 1:15 pm - Soumitra (Mid Mess: Requested to all borders participate a discussion for August months account at 10:30pm . vanue - Niru's room.🙏
# result : []
# line:
#  31/08/23, 6:27 pm - +91 74072 29043: IMG-20230831-WA0001.jpg (file attached)
# result : []
# line:
#  Fund Balance:Rs 3609. Entrance fees still not received from 1) Niru - Rs 500 2) Subhadip - Rs 1000.
# result : []
# line:
#  31/08/23, 11:52 pm - Saikat: IMG-20230831-WA0002.jpg (file attached)
# result : []
# line:
#  যাদের যাদের বাজারে ছাড় আছে নিচে দেওয়া আছে। বাকিরা সবাই 5 তারিখের মধ্যে নাম বসিয়ে দেবে।
# result : []
# line:
#  01/09/23, 12:36 am - Soumitra (Mid Mess: IMG-20230901-WA0000.jpg (file attached)
# result : []
# line:
#  please submitted money within 05.09.2023
# result : []
# line:
#  02/09/23, 8:20 am - +91 82509 91152: <Media omitted>
# result : []
# line:
#  02/09/23, 3:06 pm - +91 82509 91152: <Media omitted>
# result : []
# line:
#  02/09/23, 6:14 pm - +91 82509 91152: রঞ্জিত রুমে নেই তাই ইলেকট্রিক বিলের হিসেব করতে দেরি হচ্ছে।
# result : []
# line:
#  02/09/23, 6:21 pm - Tapas Pradhan: Rate meal hobe
# result : []
# line:
#  02/09/23, 9:46 pm - Ranjit Mess Sadhana: Kal k ami ja66i
# result : []
# line:
#  02/09/23, 9:46 pm - Ranjit Mess Sadhana: Kal morning a amar meal hobe... Ranjit Roy
# result : []
# line:
#  02/09/23, 10:00 pm - +91 78110 67881: Kal sokal theke amar meal continue on hobe.      Sudip sing
# result : []
# line:
#  02/09/23, 10:35 pm - +91 76027 79174: Kal sudu sokal bela mill off tak be Niru Mandi 🙏👍
# result : []
# line:
#  03/09/23, 9:35 pm - +91 82509 91152: This message was deleted
# result : []
# line:
#  03/09/23, 9:40 pm - +91 82509 91152: IMG-20230903-WA0001.jpg (file attached)
# result : []
# line:
#  মেসের ইলেকট্রিক বিলের টাকা সবাই ৯ তারিখের মধ্যে জমা করো।
# result : []
# line:
#  03/09/23, 9:40 pm - +91 82509 91152: IMG-20230903-WA0002.jpg (file attached)
# result : []
# line:
#  04/09/23, 3:46 pm - Saikat: IMG-20230904-WA0000.jpg (file attached)
# result : []
# line:
#  যারা যারা টাকা দাওনি টাকা দিবে
# result : []
# line:
#  04/09/23, 9:01 pm - Saikat: IMG-20230904-WA0001.jpg (file attached)
# result : []
# line:
#  যারা যারা এখনো নাম বসাওনি বাজারের। নাম বসাও নইলে আমি বারোটার পর নাম বসিয়ে দেবো।
# result : []
# line:
#  05/09/23, 1:53 pm - Saikat: কাকিমা আসবেনা -
# result : []
# line:
#  বুধবার সকাল গ্রুপ 4 (মনি শংকর, সুশোভন, মনোজ, রঞ্জিত )
# result : []
# line:
#
# result : []
# line:
#  বুধবার সন্ধ্যে গ্রুপ 5 (সৌমিত্র শুভঙ্কর, আশীষ, অলকেশ )
# result : []
# line:
#
# result : []
# line:
#  বৃহস্পতিবার সকাল গ্রুপ 1 ( পূর্ণ, তাপস, সুদীপ, সন্দ্বীপ )
# result : []
# line:
#
# result : []
# line:
#  রান্না করতে হবে <This message was edited>
# result : []
# line:
#  05/09/23, 5:05 pm - +91 99335 77215: Aj night e amar meal off thakbe....kal morning theke abar meal continue    hbe
# result : []
# line:
#  05/09/23, 10:06 pm - +91 76027 79174: Continue mil off tak be...Niru Mandi
# result : []
# line:
#  06/09/23, 1:51 pm - Saikat: আজ জন্মাষ্টমীর কারণে অনেকে মাংস না খাবার কথা বলছে।
# result : []
# line:
#  তাই আজকে সন্ধ্যায় যাদের যাদের মিল হবে তারা একটু জানাও মাংস হবে না খিচুড়ি হবে।
# result : []
# line:
#
# result : []
# line:
#  আজ ৫:৪৫ pm. এরমধ্যে প্রত্যেকেই নিজের নিজের মতামত দাও।
# result : []
# line:
#
# result : []
# line:
#  বেশি সংখ্যক সদস্য যেটাই বলবে সেটাই হবে।
# result : []
# line:
#  06/09/23, 1:57 pm - Sandip Maity Mess Sadhana: খিচুড়ি হোক।।।।👍👍
# result : []
# line:
#  06/09/23, 2:04 pm - Monisankar Pradhan Mess: মাংস হোক
# result : []
# line:
#  06/09/23, 2:46 pm - +91 99335 77215: রান্না কারী দের যেটা সুবিধা সেটাই হোক‌ (মাংস/খেচুড়ি)
# result : []
# line:
#  06/09/23, 2:50 pm - +91 80012 92291: Manso hok.
# result : []
# line:
#  06/09/23, 5:11 pm - Ranjit Mess Sadhana: মাংস হোক....
# result : []
# line:
#  06/09/23, 5:55 pm - Saikat: তাহলে মাংস টিম জিতে গেছে
# result : []
# line:
#  সুতরাং মাংস হচ্ছে
# result : []
# line:
#  06/09/23, 10:48 pm - +91 76027 79174: Kal k sokal bela teke continue mil  chalu  hbe ......Niru Mandi 🙏👍
# result : []
# line:
#  07/09/23, 6:58 pm - Saikat: আজ দুপুরে কে মিল খাওনি জানাও????
# result : []
# line:
#  08/09/23, 8:55 am - Saikat: কাল রাতের খাবারও কেউ একজন খাওনি কে খাওনি?
# result : []
# line:
#  যে খাওনি সে জানাও।
# result : []
# line:
#  চালের  এত দাম বেড়েছে না খেলে জানিয়ে দিতে পারো তো এভাবে ভাত নষ্ট করাটা কি ঠিক হচ্ছে????? <This message was edited>
# result : []
# line:
#  08/09/23, 8:56 am - Susovan (Mess: Fine koro je khai niii. Hok fine
# result : []
# line:
#  08/09/23, 11:12 pm - +91 82509 91152: এখনো যারা টাকা জমা করো নি তারা কালকের মধ্যে টাকা জমা করো।
# result : []
# line:
#  09/09/23, 5:27 pm - +91 76027 79174: Rateo mil off tak be.....Niru Mandi 🙏👍
# result : []
# line:
#  09/09/23, 6:22 pm - Saikat: Sakal e hobe?
# result : []
# line:
#  09/09/23, 6:29 pm - +91 76027 79174: Ami sms kor bo ami
# result : []
# line:
#  09/09/23, 6:36 pm - Saikat: Ok
# result : []
# line:
#  09/09/23, 7:46 pm - Lob: Sudhu Kal sokaler meal off thak be
# result : []
# line:
#  09/09/23, 7:47 pm - Saikat: Ok
# result : []
# line:
#  10/09/23, 12:53 pm - Saikat: যারা যারা অসুবিধা  জানিয়েছো তারা বাদে ৭০০ টাকা করে দিয়ে দিবে সবাই।
# result : []
# line:
#  10/09/23, 3:56 pm - Monisankar Pradhan Mess: রাত থেকে আমার মিল চালু হবে- মনিশংকর
# result : []
# line:
#  10/09/23, 4:33 pm - +91 832 874 4399: Aj rater meal ta sudhu off hobe kal sokal theke abar chalu hobe......subhadip
# result : []
# line:
#  10/09/23, 5:11 pm - Lob: Rate meal on hobe 👍
# result : []
# line:
#  10/09/23, 8:14 pm - +91 76027 79174: Kal k sokal bela teke continue mil on hbe...Niru Mandi 🙏👍
# result : []
# line:
#  10/09/23, 8:38 pm - Saikat: Ok
# result : []
# line:
#  11/09/23, 6:23 am - +91 83919 42989: Dupure Amar meal habe
# result : []
# line:
#  11/09/23, 6:24 am - +91 83919 42989: Alokesh , meal habe
# result : []
# line:
#  11/09/23, 8:41 am - Saikat: তোমার আজ মিলটা হয়েছে।👍
# result : []
# line:
#
# result : []
# line:
#  কিন্তু প্রত্যেক সদস্যের কাছে আমার অনুরোধ সকালের মিল চালু বা বন্ধ রাত্রি 11:15 মধ্যে জানাবে।
# result : []
# line:
#  আর রাতের মিল চালু বা বন্ধ সন্ধ্যা ছটার মধ্যে জানাবে। <This message was edited>
# result : []
# line:
#  13/09/23, 6:29 pm - Lob: Aj meat... Kota 160/kg
# result : []
# line:
#  13/09/23, 6:30 pm - Lob: Ja atodiner Mess jiboner highest rate
# result : []
# line:
#  13/09/23, 6:59 pm - Sasti: Oi sob bujena dupura soyabin khaye6ho rata 10 pis kora lagba
# result : []
# line:
#  13/09/23, 8:55 pm - +91 99335 77215: কাটা না গোটা?
# result : []
# line:
#  13/09/23, 10:38 pm - Lob: Gota 🥹
# result : []
# line:
#  15/09/23, 1:20 pm - Saikat: যারা যারা হাজার টাকা করে দাওনি  দিয়ে দিবে।
# result : []
# line:
#  15/09/23, 10:47 pm - +91 76027 79174: Kal sokal bela mil off tak be....Niru Mandi 🙏👍
# result : []
# line:
#  15/09/23, 10:57 pm - Saikat: sudhu sokal?
# result : []
# line:
#  15/09/23, 11:26 pm - Saikat: IMG-20230916-WA0000.jpg (file attached)
# result : []
# line:
#  রবিবার সকাল- গ্রুপ 2, সোমবার সকাল -গ্রুপ 3।  রান্না করতে হবে।
# result : []
# line:
#  16/09/23, 5:41 am - +91 76027 79174: Hai
# result : []
# line:
#  16/09/23, 7:14 am - Saikat: Ok
# result : []
# line:
#  16/09/23, 10:51 pm - +91 76027 79174: Kal k continue mil off tak be... Niru Mandi 🙏👍
# result : []
# line:
#  16/09/23, 10:52 pm - Saikat: Ok
# result : []
# line:
#  16/09/23, 11:39 pm - +91 82509 91152: IMG-20230916-WA0007.jpg (file attached)
# result : []
# line:
#  17/09/23, 3:52 pm - JOYPRAKASH MAHATA: Ratay meal hobay na
# result : []
# line:
#  17/09/23, 7:04 pm - Lob: Sudhumatra kal sokaler meal off thakbe.....👍
# result : []
# line:
#  17/09/23, 8:41 pm - Saikat: Sudhu rat na continue off?
# result : []
# line:
#  17/09/23, 8:47 pm - JOYPRAKASH MAHATA: Yes
# result : []
# line:
#  17/09/23, 8:48 pm - Saikat: konta yes?
# result : []
# line:
#  17/09/23, 8:48 pm - JOYPRAKASH MAHATA: Sob yes
# result : []
# line:
#  18/09/23, 4:45 pm - Lob: Rate meal on hobe 👍
# result : []
# line:
#  22/09/23, 9:32 pm - Saikat: মনোজের রুমের সামনে জানালায় কার টাকা পড়ে আছে  উপযুক্ত প্রমাণ দিয়ে নিয়ে নিবে? মনোজ এর কাছ থেকে
# result : []
# line:
#  23/09/23, 5:32 pm - +91 76027 79174: Sudu Ratre mil off tak be...Niru Mandi 🙏👍
# result : []
# line:
#  23/09/23, 6:10 pm - Tapas Pradhan: Rate meal hobe
# result : []
# line:
#  23/09/23, 6:30 pm - Saikat: ok
# result : []
# line:
#  24/09/23, 8:45 am - +91 74072 29043: IMG-20230924-WA0000.jpg (file attached)
# result : []
# line:
#  24/09/23, 8:54 am - +91 74072 29043: IMG-20230924-WA0001.jpg (file attached)
# result : []
# line:
#  Hi Manager, add Rs 55 to my account.
# result : []
# line:
#  24/09/23, 6:03 pm - Saikat: আগামীকাল সকাল বেলা গ্রুপ ফোর রান্না করবে
# result : []
# line:
#  24/09/23, 9:47 pm - Saikat: IMG-20230924-WA0006.jpg (file attached)
# result : []
# line:
#  25/09/23, 4:47 pm - +91 76027 79174: Sudu Ratre mil off tak be...Niru Mandi 🙏👍
# result : []
# line:
#  25/09/23, 10:15 pm - JOYPRAKASH MAHATA: Kal meal off hobay
# result : []
# line:
#  25/09/23, 10:15 pm - JOYPRAKASH MAHATA: Jokhon hobay janabo
# result : []
# line:
#  25/09/23, 10:16 pm - Saikat: Ok
# result : []
# line:
#  26/09/23, 5:15 pm - JOYPRAKASH MAHATA: Ratay meal hobay
# result : []
# line:
#  26/09/23, 5:44 pm - Saikat: ok
# result : []
# line:
#  26/09/23, 7:47 pm - Lob: Kal sokale meal off thakbe....
# result : []
# line:
#  Kal rate meal hobe 👍
# result : []
# line:
#  26/09/23, 9:54 pm - Susovan (Mess: Kall sokal theke meal hobe kemon. Susovan
# result : []
# line:
#  27/09/23, 7:32 pm - +91 74072 29043: IMG-20230927-WA0000.jpg (file attached)
# result : []
# line:
#  Managership details
# result : []
# line:
#  27/09/23, 7:32 pm - +91 74072 29043: New candidates for Managership from next(October)month onwards:
# result : []
# line:
#
# result : []
# line:
#  Alokesh Barman( Entry month - June, 2023)
# result : []
# line:
#
# result : []
# line:
#  Sudip Singh ( Entry month - August, 2023)
# result : []
# line:
#
# result : []
# line:
#  Subhadip Sahoo ( Entry month - August, 2023)
# result : []
# line:
#  28/09/23, 10:56 am - Saikat: আগামী শনিবার (30/9/23) সকাল বেলা মাসের শেষ দিনের জন্য ম্যানেজারসিপ থেকে ডিমের পরিবর্তে মাংস হবে তাই প্রত্যেকে চেষ্টা করবে থাকার।
# result : []
# line:
#  28/09/23, 1:56 pm - Prabin Pramanik: Meat should be done at night instead of morning.
# result : []
# line:
#  28/09/23, 2:20 pm - +91 99335 77215: Morning e ডিম and Night e মাংস হোক 😉
# result : []
# line:
#  28/09/23, 2:26 pm - Ranjit Mess Sadhana: সহমত
# result : []
# line:
#  28/09/23, 2:26 pm - Lob: Hok
# result : []
# line:
#  28/09/23, 9:10 pm - Saikat: ডিম মাংস দুটোই যখন খাব বলছো সবাই তাহলে রাতেই হোক।
# result : []
# line:
#  28/09/23, 11:03 pm - +91 76027 79174: Kal teke continue mil off tak be....Niru Mandi 🙏👍
# result : []
# line:
#  28/09/23, 11:11 pm - Saikat: Ok
# result : []
# line:
#  29/09/23, 10:30 pm - +91 76027 79174: Kal k sokal theke mil on hbe...Niru Mandi 🙏👍
# result : []
# line:
#  29/09/23, 10:34 pm - Saikat: ok
# result : []
# line:
#  30/09/23, 12:38 pm - +91 74072 29043: IMG-20230930-WA0001.jpg (file attached)
# result : []
# line:
#  Fund balance is Rs 4499, excluding Rs 500 which is not yet received from "NIRU MANDI".
# result : []
# line:
#  30/09/23, 12:41 pm - +91 74072 29043: Candidates for Managership from October month onwards:
# result : []
# line:
#
# result : []
# line:
#  1) Alokesh Barman(4 months complete in Mess)
# result : []
# line:
#  2) Sudip Singh ( 2 months complete in Mess)
# result : []
# line:
#  3) Subhadip Sahoo (2 months complete in Mess)
# result : []
# line:
#  30/09/23, 5:57 pm - Saikat: আজ 10.30pm সময় নিরুর রুমে সেপ্টেম্বর মাসের হিসাব নিকাশ সংক্রান্ত মিটিং হবে।
# result : []
# line:
#  01/10/23, 12:06 am - Saikat: IMG-20231001-WA0000.jpg (file attached)
# result : []
# line:
#  সবাই 5 তারিখের মধ্যে টাকা মিটিয়ে দিবে👍
# result : []
# line:
#  01/10/23, 12:09 am - Saikat: সবাই 10 তারিখের মধ্যে কাকিমার পুজোর বোনাস বাবদ 85 টাকা শুভদীপ এর কাছে জমা করে দিবে। <This message was edited>
# result : []
# line:
#  01/10/23, 12:09 am - Lob: 85 holo to
# result : []
# line:
#  01/10/23, 12:10 am - Saikat: Hmmm👍👍
# result : []
# line:
#  01/10/23, 12:20 am - Ranjit Mess Sadhana: কাল সকাল থেকে আমার আহারের বন্দোবস্ত সম্পূর্ণ ভাবে বন্ধ থাকিবে। আর রাতে পুনরায় আমার আহারের বন্দোবস্ত হবে।
# result : []
# line:
#
# result : []
# line:
#  রঞ্জিত রায়
# result : []
# line:
#  01/10/23, 12:27 am - +91 832 874 4399: Kal sokale amar meal off thakbe. Ratre abar chalu hobe.
# result : []
# line:
#  Subhadip
# result : []
# line:
#  01/10/23, 8:30 am - Saikat: IMG-20231001-WA0001.jpg (file attached)
# result : []
# line:
#  Online e keu taka pathale pathate paro etai
# result : []
# line:
#  01/10/23, 10:05 am - +91 74072 29043: IMG-20231001-WA0002.jpg (file attached)
# result : []
# line:
#  Paid
# result : []
# line:
#  01/10/23, 10:11 am - +91 83919 42989: 1-5 September er modhya sabai kichu meal er taka dia dabe ,from-manager
# result : []
# line:
#  01/10/23, 5:57 pm - +91 83919 42989: Meal on korte hole
# result : []
# line:
#  Morning- ager rate 11pm
# result : []
# line:
#  Night-sondhe 6pm
# result : []
# line:
#  From- manager
# result : []
# line:
#  01/10/23, 8:31 pm - Subhankar(mess: Kal sakale meal hobe.
# result : []
# line:
#  Subhankar
# result : []
# line:
#  01/10/23, 10:50 pm - +91 76027 79174: Kal theke continue mil off tak be....Niru Mandi 🙏👍
# result : []
# line:
#  02/10/23, 3:19 pm - Monisankar Pradhan Mess: রাত থেকে আমার মিল চালু হবে- মনিশংকর
# result : []
# line:
#  02/10/23, 4:10 pm - Sandip Maity Mess Sadhana: Ajj night theke amar meal continue on hobe...
# result : []
# line:
#  *Sandip*
# result : []
# line:
#  02/10/23, 10:43 pm - +91 76027 79174: Kal k sokal theke continue mil on hbe... Niru Mandi 🙏👍
# result : []
# line:
#  03/10/23, 6:55 pm - Lob: https://fb.watch/nrOHcLZVYb/?mibextid=VhDh1V
# result : []
# line:
#  03/10/23, 9:00 pm - Saikat: আগামীকাল সকাল থেকে আমার মিল বন্ধ থাকবে। সৈকত
# result : []
# line:
#  03/10/23, 11:11 pm - Saikat: আমি দুদিন থাকছি না যদি কেউ টাকা দাও শুভজিৎ এর কাছে দিতে পারো।
# result : []
# line:
#  05/10/23, 8:34 pm - Saikat: কাল সকাল থেকে মিল হবে
# result : []
# line:
#  06/10/23, 4:25 pm - +91 76027 79174: Ajk rat theke continue mil off tak be...Niru Mandi 🙏👍
# result : []
# line:
#  06/10/23, 5:57 pm - +91 82509 91152: AJ rat thaka amar meal chalu korba...subhajit
# result : []
# line:
#  06/10/23, 10:58 pm - Tapas Pradhan: Kal sokale meal off thakbe
# result : []
# line:
#  07/10/23, 8:27 am - +91 832 874 4399: যারা এই টাকাটা দাওনি তাড়াতাড়ি দাও ।।
# result : []
# line:
#
# result : []
# line:
#  শুভদীপ
# result : []
# line:
#  07/10/23, 10:44 am - Saikat: যারা যারা টাকা দাওনি কালকের মধ্যে টাকা দাও কাকিমা টাকা খুজছেন।
# result : []
# line:
#  07/10/23, 2:50 pm - Lob: 5.tarik to last date.... Jar problem ache se to janabe.... Manager tumi.. Nam ullek Kore bolo.
# result : []
# line:
#  Niyom to sobai jane...
# result : []
# line:
#  Pujar masse late hobeii  ba kno kakima k taka dite.
# result : []
# line:
#  07/10/23, 2:53 pm - Saikat: দুজনের বাকি আছে অলকেশ আর সুদীপ
# result : []
# line:
#  07/10/23, 3:30 pm - +91 83919 42989: Aj rater meal habe
# result : []
# line:
#  Alakesh
# result : []
# line:
#  07/10/23, 5:54 pm - Tapas Pradhan: Rate meal hobe
# result : []
# line:
#  07/10/23, 8:01 pm - +91 78110 67881: Kal sokal theke amar meal continue on hobe. Sudip
# result : []
# line:
#  08/10/23, 1:07 am - +91 80012 92291 started a call
# result : []
# line:
#  08/10/23, 2:56 pm - +91 76027 79174: Ajk Rat theke continue mil on hbe .... Niru Mandi 🙏👍
# result : []
# line:
#  08/10/23, 5:44 pm - +91 832 874 4399: কাকিমার পুজোর বোনাস যারা দাওনি তাড়াতাড়ি দাও
# result : []
# line:
#  08/10/23, 5:52 pm - +91 99335 77215: রাতে আমার মিল বন্ধ থাকবে... কাল সকাল থেকে আবার মিল কন্টিনিউ হবে... প্রসেনজিৎ
# result : []
# line:
#  08/10/23, 10:47 pm - Prabin Pramanik: বি:দ্র:---- কোথাও যেন newspaper এর সমস্যাটা থেকেই যাচ্ছে, কোনো মতে সমস্যার সমাধান হচ্ছে না। It's just like a man made error. অনেকবারই বলা হয়েছে দুপুর 12:00 pm থেকে  2:00 pm অবদি newspaper নীচে থাকবে, কিন্তু মানা হচ্ছে না। ইদানীং কিছু দিন ধরে লক্ষ্য করছি newspaper সম্ভবত সকাল 11:00 am নাগাত ওপরে উঠে যায় আর নামানো হয় 1:30 pm নাগাদ। এতোক্ষণ ওটাকে নিছকই আটকে রাখা হচ্ছে । যাইহোক  newspaper আটকে রাখা হচ্ছে "সেটা বড়ো কথা নয়, বড়ো কথা হলো যে" আগামীকাল থেকে যদি newspaper 12:00 pm এ না দেখতে পাই ( যেখানে রাখা থাকে ) তাহলে পরের দিন থেকে newspaper ফালাফাল করবো এবং টুকরো টুকরো করে dustbin এ ফেলবো।
# result : []
# line:
#  প্রত্যেকর দৃষ্টিগোচর রইল।
# result : []
# line:
#
# result : []
# line:
#  ---Prabin Pramanik---
# result : []
# line:
#  09/10/23, 8:43 pm - +91 832 874 4399: যারা যারা কাকিমার টাকা (পুজোর বোনাস) দাওনি তাড়াতাড়ি দাও। কাকিমা টাকা চাইছেন। মাত্র 12 জন টাকা জমা দিয়েছে। টাকা জমা দেওয়ার জন্য শুভদীপ এর যোগাযোগ করুন। সবাইকে অনুরোধ টাকাটা তাড়াতাড়ি জমা করুন।
# result : []
# line:
#
# result : []
# line:
#  ইতি
# result : []
# line:
#  শুভদীপ সাউ
# result : []
# line:
#  09/10/23, 10:42 pm - +91 76027 79174: Kal sokal theke continue mil off tak be....Niru Mandi 🙏👍
# result : []
# line:
#  10/10/23, 11:38 am - Lob: IMG-20231010-WA0000.jpg (file attached)
# result : []
# line:
#  10/10/23, 11:38 am - Lob: IMG-20231010-WA0001.jpg (file attached)
# result : []
# line:
#  11/10/23, 9:59 am - +91 832 874 4399: Susovon da kakima pujor bonus ta dao...tumi immediate taka pathao..
# result : []
# line:
#  11/10/23, 10:12 am - Susovan (Mess: Pathia diachi online a ektu collect kore naw purna r kach theke
# result : []
# line:
#  11/10/23, 10:13 am - +91 832 874 4399: Hmm peyegechi
# result : []
# line:
#  11/10/23, 11:22 pm - +91 82509 91152: Kal sokal thaka amar continue meal off thakba...Subhajit
# result : []
# line:
#  15/10/23, 9:26 am - +91 83919 42989: Kakimar sarir kharap er Janna rate aste par be na
# result : []
# line:
#  Tai gp.no -1 rate ranna kor te habe. From manager
# result : []
# line:
#  15/10/23, 5:19 pm - +91 82509 91152: Aj rat thaka amar meal continue 📴 thakba... Subhajit
# result : []
# line:
#  16/10/23, 5:04 pm - +91 82509 91152: Rat thaka meal chalu hoba .. Subhajit
# result : []
# line:
#  17/10/23, 12:28 am - Ranjit Mess Sadhana: IMG-20231017-WA0000.jpg (file attached)
# result : []
# line:
#  18/10/23, 11:33 am - +91 83919 42989: Astamir sakal to Dasami rat parjanta mess er meal off thak be.
# result : []
# line:
#  From-manager
# result : []
# line:
#  18/10/23, 11:37 am - +91 83919 42989: IMG-20231018-WA0000.jpg (file attached)
# result : []
# line:
#  Sabar Dak ase ektu dekhe nabe
# result : []
# line:
#  19/10/23, 2:29 pm - Monisankar Pradhan Mess: Rat theke continue meal off thakbe - Monisankar
# result : []
# line:
#  19/10/23, 5:30 pm - +91 832 874 4399: Rat theke amar meal ta continue off thakbe .....subhadip <This message was edited>
# result : []
# line:
#  20/10/23, 3:48 pm - Tapas Pradhan: Rat Thake meal off thakbe
# result : []
# line:
#  20/10/23, 3:51 pm - JOYPRAKASH MAHATA: Ratay meal hobay
# result : []
# line:
#  20/10/23, 10:31 pm - +91 83919 42989: Kal kakima asban na tai
# result : []
# line:
#  G.p-no-2 ranna kor be (sakale) from,manager
# result : []
# line:
#  21/10/23, 2:21 pm - +91 83919 42989: Sakaler anumoti te aj rate dupurer vat thak be.
# result : []
# line:
#  Nijeder mato kore ke nebe. From-manager
# result : []
# line:
#  25/10/23, 6:24 am - Tapas Pradhan: Aj sokal thake meal on hobe
# result : []
# line:
#  25/10/23, 10:36 am - +91 83919 42989: IMG-20231018-WA0000.jpg (file attached)
# result : []
# line:
#  Sabar Dak ase ektu dekhe nabe
# result : []
# line:
#  25/10/23, 10:37 am - +91 83919 42989: Kara jabena Jana be.
# result : []
# line:
#  Kal khawar Dak ase.
# result : []
# line:
#  25/10/23, 10:40 am - +91 99335 77215: আমি যাবো না(প্রসেনজিৎ)
# result : []
# line:
#  25/10/23, 10:41 am - +91 832 874 4399: Ami jete parbona ... subhadip
# result : []
# line:
#  25/10/23, 10:51 am - Sandip Maity Mess Sadhana: Amio👍👍👍
# result : []
# line:
#  25/10/23, 11:26 am - +91 83919 42989: Alakesh, Ami jabo na
# result : []
# line:
#  25/10/23, 11:29 am - Subhankar(mess: Ami jabo na
# result : []
# line:
#  25/10/23, 11:29 am - +91 82509 91152: Ai vaba na ask kora Kara kal mesa thakb meal cholba but jaba na tader ka reply deta bolo.........
# result : []
# line:
#  25/10/23, 11:38 am - +91 82509 91152: Jadi 3 jon ba tar basi meal hoy thle kalka mese Rana hoba
# result : []
# line:
#  25/10/23, 10:23 pm - +91 80012 92291: কাল সকাল বেলা মেসের হাঁড়ি বন্ধ থাকবে। কারণ শুভজিত -দার বাড়িতে অন্নপ্রাশন এর নিমন্ত্রণ আছে।
# result : []
# line:
#  26/10/23, 12:06 pm - +91 80012 92291: IMG-20231026-WA0001.jpg (file attached)
# result : []
# line:
#  26/10/23, 12:48 pm - +91 80012 92291: Sobai ready hoye thk 1.20pm jaba hba.
# result : []
# line:
#  26/10/23, 2:13 pm - +91 82509 91152: IMG-20231026-WA0002.jpg (file attached)
# result : []
# line:
#  26/10/23, 5:00 pm - JOYPRAKASH MAHATA: Ratay meal hobay
# result : []
# line:
#  26/10/23, 5:19 pm - Susovan (Mess: Ami susovan bolchi agamikal Amar bazar ache jodi kaw bazar ti kore dite . Ami jete pari ni karon Ami 4 din dhore prochondo jor ekhono thik hoini . Tai jete pari niii. Jodi kaw bazar kore dite.
# result : []
# line:
#  26/10/23, 7:23 pm - +91 832 874 4399: Kal sokal theke amar meal on hobe ...... subhadip
# result : []
# line:
#  26/10/23, 9:22 pm - +91 80012 92291: ডিম ভাজা আছে নিয়ে নেবে সবাই।
# result : []
# line:
#  27/10/23, 9:40 pm - +91 80012 92291: Kal kakima asbeni tai sakale group -3 ranna korbe.
# result : []
# line:
#  27/10/23, 9:58 pm - Ranjit Mess Sadhana: 3 no a K K a6e...?
# result : []
# line:
#  27/10/23, 10:46 pm - Lob: Kal Jodi egg hoy tahole amar meal er dim kacha takbe 👍
# result : []
# line:
#  27/10/23, 11:09 pm - +91 80012 92291: Kal niramish hba naki dim hb. Taratari janiya dao.
# result : []
# line:
#  27/10/23, 11:10 pm - Sasti: Kal niramish hoba
# result : []
# line:
#  29/10/23, 6:23 am - +91 74072 29043: IMG-20231029-WA0000.jpg (file attached)
# result : []
# line:
#  Fund balance is Rs 3564, excluding Rs 500 which is not yet received from "NIRU MANDI".
# result : []
# line:
#  29/10/23, 6:27 am - +91 74072 29043: Candidates for Managership for upcoming months:
# result : []
# line:
#
# result : []
# line:
#  1) Sudip Singh
# result : []
# line:
#  2) Subhadip Sahoo
# result : []
# line:
#  29/10/23, 2:46 pm - Sasti: Aj rata amr meal of thakba (sosthi)
# result : []
# line:
#  29/10/23, 2:50 pm - +91 99335 77215: Aj night e meal off thakbe(prasenjit) kal morning e meal হবে..
# result : []
# line:
#  29/10/23, 3:36 pm - Subhankar(mess: Meal hobe
# result : []
# line:
#
# result : []
# line:
#  Subhankar
# result : []
# line:
#  29/10/23, 4:54 pm - Saikat: Amar meal hobe aj thake
# result : []
# line:
#  saikat
# result : []
# line:
#  29/10/23, 9:39 pm - +91 78110 67881: Kal sokal theke amar meal continue on hobe.
# result : []
# line:
#  Sudip
# result : []
# line:
#  29/10/23, 10:02 pm - Sandip Maity Mess Sadhana: Kal sokal theke Amaro meal on hobe...
# result : []
# line:
#  *Sandip*
# result : []
# line:
#  29/10/23, 10:03 pm - Subhankar(mess: This message was deleted
# result : []
# line:
#  29/10/23, 11:38 pm - +91 76027 79174: Kal sokal bela teke continue mil on hbe...Niru Mandi 🙏👍
# result : []
# line:
#  30/10/23, 11:05 am - +91 80012 92291: Aj rate managership thke meat hba.karao jdi asubidha a6a janaba
# result : []
# line:
#  31/10/23, 6:28 am - +91 83919 42989: Rate kar meal off thak be
# result : []
# line:
#  Janao. Hisab korte habe. aj rate meeting habe.-from manager
# result : []
# line:
#  31/10/23, 7:46 am - +91 99335 77215: Night e amar meal off thakbe- prasenjit
# result : []
# line:
#  31/10/23, 7:14 pm - +91 83919 42989: Aj rat 10:15pm meeting habe. From-manager
# result : []
# line:
#  31/10/23, 11:59 pm - +91 83919 42989: IMG-20231101-WA0000.jpg (file attached)
# result : []
# line:
#  Final hisab.
# result : []
# line:
#  01/11/23, 12:03 am - +91 83919 42989: Taka jar jar baki ase  5th November er madhe Diya debe. From-manager, Alakesh
# result : []
# line:
#  01/11/23, 4:22 pm - +91 78110 67881: IMG-20231101-WA0002.jpg (file attached)
# result : []
# line:
#  যারা যারা টাকা দাওনি টাকা দিবে
# result : []
# line:
#  03/11/23, 6:18 pm - JOYPRAKASH MAHATA: Manager aj ki chicken hobay
# result : []
# line:
#  03/11/23, 6:19 pm - Subhankar(mess: Hok
# result : []
# line:
#  03/11/23, 6:19 pm - +91 832 874 4399: Hok
# result : []
# line:
#  03/11/23, 6:20 pm - +91 78110 67881: না
# result : []
# line:
#  03/11/23, 6:20 pm - +91 82509 91152: Hola valoi hoto
# result : []
# line:
#  03/11/23, 6:22 pm - Purna(mess-mid: Hok...
# result : []
# line:
#  03/11/23, 6:26 pm - +91 80012 92291: Hok
# result : []
# line:
#  03/11/23, 6:26 pm - Sasti: Hok
# result : []
# line:
#  03/11/23, 6:27 pm - Sandip Maity Mess Sadhana: Hok👍👍👍👍
# result : []
# line:
#  03/11/23, 6:36 pm - Sandip Maity Mess Sadhana: This message was deleted
# result : []
# line:
#  04/11/23, 10:36 am - +91 83919 42989: Jader ager maser(October) taka baki ase kal(5th) diya debe. Alakesh
# result : []
# line:
#  05/11/23, 2:57 pm - Lob: IMG-20231105-WA0000.jpg (file attached)
# result : []
# line:
#  Pariskar aktu baki ache.... Aj ker group aktu dekhe nio plz
# result : []
# line:
#  05/11/23, 3:03 pm - Purna(mess-mid: ব্রাশ দিয়ে এর চেয়ে ভালো পরিষ্কার করা যাচ্ছে না....
# result : []
# line:
#  05/11/23, 3:10 pm - Lob: IMG-20231105-WA0001.jpg (file attached)
# result : []
# line:
#  Done 🥰😌
# result : []
# line:
#  05/11/23, 3:11 pm - Purna(mess-mid: প্রত্যেকবারে যেন এরকম পরিষ্কার থাকে....
# result : []
# line:
#  05/11/23, 3:12 pm - Lob: Setai bola sobai k...
# result : []
# line:
#  05/11/23, 3:16 pm - Lob: Karan urine ta daily besi bebohar hoy tai sobar kache amar request tara jeno Aktu Vlo kore monojog diye... Daisara na vebe barir jinis vebe.. Pariskar ta Kore....
# result : []
# line:
#
# result : []
# line:
#
# result : []
# line:
#  Ato kotha boltam na samne room to tai gandho ta Aktu ase arr ki 😌🤨
# result : []
# line:
#  05/11/23, 6:04 pm - Tapas Pradhan: Rate amar meal off thakbe
# result : []
# line:
#  Sokale hobe
# result : []
# line:
#  05/11/23, 10:03 pm - Susovan (Mess: Kall sokal theke amar meal hobe susovan
# result : []
# line:
#  05/11/23, 10:08 pm - +91 82509 91152: Kal sokal thaka amar meal hoba... Subhajit
# result : []
# line:
#  07/11/23, 10:35 pm - JOYPRAKASH MAHATA: Kal sokal a meal 📴 thakbay
# result : []
# line:
#  08/11/23, 10:58 am - JOYPRAKASH MAHATA: Ratay meal hobay
# result : []
# line:
#  08/11/23, 4:48 pm - +91 82509 91152: Rate amar meal 📴 thakba...sokala meal hoba
# result : []
# line:
#  09/11/23, 10:02 pm - +91 82509 91152: Kal sokal thaka  continue meal 📴 thakba
# result : []
# line:
#  Subhajit
# result : []
# line:
#  10/11/23, 5:16 pm - Saikat: শুধুমাত্র আজ রাতের মিলটা অফ হবে সৈকত
# result : []
# line:
#  10/11/23, 10:19 pm - Tapas Pradhan: Kal Sokale meal off thakbe
# result : []
# line:
#  Rate hobe
# result : []
# line:
#  11/11/23, 5:18 pm - Saikat: শুধুমাত্র আজ রাতের মিলটা অফ থাকবে।
# result : []
# line:
#  সৈকত
# result : []
# line:
#  11/11/23, 5:45 pm - Susovan (Mess: Aj rath theke meal off thakbe continue susovan.
# result : []
# line:
#  11/11/23, 8:03 pm - +91 78110 67881: কাকিমা আসবেনা -
# result : []
# line:
#  রবিবার সকাল গ্রুপ 5 (সৌমিত্র, শুভঙ্কর, আশীষ, অলকেশ )                                                 ‌
# result : []
# line:
#  রবিবার সন্ধ্যে গ্রুপ  2 (প্রসেনজিৎ,লব,জয়প্রকাশ,ষষ্ঠী,শুভদীপ)
# result : []
# line:
#
# result : []
# line:
#  রান্না করতে হবে
# result : []
# line:
#  11/11/23, 8:50 pm - +91 99335 77215: 1 number grup kothai gel
# result : []
# line:
#  11/11/23, 8:59 pm - +91 78110 67881: 1 নম্বর গ্ৰুপ কালকে সবাই বাড়ি চলে যাবে,
# result : []
# line:
#  11/11/23, 9:01 pm - +91 99335 77215: Kalke amar meal off thakbe
# result : []
# line:
#  11/11/23, 10:05 pm - +91 82509 91152: Kalka amar meal continue 📴 thakba
# result : []
# line:
#  11/11/23, 10:45 pm - +91 83919 42989: Amar kal sakal theke meal off habe. Alakesh
# result : []
# line:
#  11/11/23, 10:47 pm - +91 99335 77215: Night off thakbe...morning e meal hbe
# result : []
# line:
#  11/11/23, 10:55 pm - Tapas Pradhan: Kal sokal thake meal off thakbe
# result : []
# line:
#  11/11/23, 10:56 pm - Sasti: Kal thaka amr meal of thakba (sosthi)
# result : []
# line:
#  12/11/23, 8:34 am - +91 74072 29043: IMG-20231112-WA0003.jpg (file attached)
# result : []
# line:
#  12/11/23, 5:19 pm - +91 832 874 4399: আগের বছর বোম কেনার জন্য 300 টাকা নেওয়া হয়েছিল.....এবারে ও 300 টাকা নেওয়া হচ্ছে ....কারো কোনো প্রবলেম থাকলে তাড়াতাড়ি জানাও......
# result : []
# line:
#
# result : []
# line:
#
# result : []
# line:
#  Manager in charge
# result : []
# line:
#  12/11/23, 7:31 pm - +91 76027 79174: IMG-20231112-WA0012.jpg (file attached)
# result : []
# line:
#  Bom gulo fata be  sabai ...aso 🧨🧨
# result : []
# line:
#  12/11/23, 7:31 pm - +91 75017 95459: Fata Tara tari
# result : []
# line:
#  12/11/23, 7:31 pm - +91 76027 79174: VID-20230505-WA0000.mp4 (file attached)
# result : []
# line:
#  12/11/23, 8:06 pm - +91 832 874 4399: সবাই 8.30 তে ছাদে চলে আসবে বোম ফাটানো হবে ।।
# result : []
# line:
#
# result : []
# line:
#
# result : []
# line:
#  M.I.C
# result : []
# line:
#  14/11/23, 9:10 pm - +91 76027 79174: IMG-20231114-WA0004.jpg (file attached)
# result : []
# line:
#  14/11/23, 9:38 pm - Saikat: আগামীকাল সকাল থেকে আমার মিল বন্ধ থাকবে
# result : []
# line:
#  সৈকত
# result : []
# line:
#  14/11/23, 9:50 pm - +91 99335 77215: Kal morning theke amar meal off thakbe(prasenjit)
# result : []
# line:
#  15/11/23, 8:44 am - Lob: Manager meal Kota hobe??
# result : []
# line:
#  15/11/23, 5:09 pm - Tapas Pradhan: Rate meal hobe
# result : []
# line:
#  15/11/23, 7:09 pm - +91 832 874 4399: Kal sokale amar meal hobe.....subhadip
# result : []
# line:
#  15/11/23, 7:38 pm - JOYPRAKASH MAHATA: Kal sokale meal hobay
# result : []
# line:
#  16/11/23, 8:32 pm - Subhankar(mess: Kal sakale meal hobe
# result : []
# line:
#
# result : []
# line:
#  Subhankar
# result : []
# line:
#  16/11/23, 8:48 pm - Saikat: আমার আগামীকাল সকাল থেকে মিল চালু হবে সৈকত
# result : []
# line:
#  16/11/23, 9:13 pm - Sandip Maity Mess Sadhana: Amaro kal sokal theke continue meal on hobe...
# result : []
# line:
#  ..........*_Sandip_*
# result : []
# line:
#  17/11/23, 4:34 pm - Lob: Aj rate mess kakima der barite nemontannno ache tai.... Kaku ase bole geche.... Sobai k jete boleche .
# result : []
# line:
#  Abong PRASENJIT dar sange lege dite bolche jodi samvab hoy to aktu rannate help kore dibe jar hobe
# result : []
# line:
#  17/11/23, 4:35 pm - Lob: Manager room aa nei college geche asle baki ja janar jene neo.....
# result : []
# line:
#  17/11/23, 4:42 pm - +91 78110 67881: আজ সন্ধ্যায় মেসে রান্না বন্ধ থাকবে। কারণ কাকুদের  বাড়িতে কার্তিক পূজা  এর নিমন্ত্রণ আছে।
# result : []
# line:
#  17/11/23, 10:39 pm - Tapas Pradhan: Kal sokale meal off thakbe
# result : []
# line:
#  Rate hobe
# result : []
# line:
#  17/11/23, 11:50 pm - Ranjit Mess Sadhana: Kal morning theke amar meal hobe....... Ranjit Roy
# result : []
# line:
#  18/11/23, 7:32 pm - +91 76027 79174: AUD-20231118-WA0002.mp3 (file attached)
# result : []
# line:
#  19/11/23, 9:58 am - +91 78110 67881: বিশেষ বিজ্ঞপ্তি:
# result : []
# line:
#  আজ world cup finale উপলক্ষে রাত্রে মাংস হবে। ২০ টাকা করে দিতে হবে। কারো কোনো আপত্তি থাকলে জানাও।
# result : []
# line:
#  20/11/23, 11:29 pm - Susovan (Mess: Kall sokal theke meal on hobe susovan.
# result : []
# line:
#  21/11/23, 5:46 pm - Tapas Pradhan: Rate meal off thakbe
# result : []
# line:
#  21/11/23, 9:36 pm - +91 83919 42989: Ami- Alakesh, ei mas(November) er sese mess charchi.parer mas(December) theke ar thak chi na.Ebang December bound meal ar dhara habe na. Good bye my all brothers 😘❤️
# result : []
# line:
#  22/11/23, 9:00 pm - +91 78110 67881: কাকিমা আসবেনা -
# result : []
# line:
#  বৃহস্পতিবার সকাল গ্রুপ 1 ( পূর্ণ, তাপস, সুদীপ, সন্দ্বীপ )
# result : []
# line:
#
# result : []
# line:
#  বৃহস্পতিবার সন্ধ্যে গ্ৰুপ 3 (প্রবীন,সৈকত,শুভজিৎ,নিরু)
# result : []
# line:
#
# result : []
# line:
#  রান্না করতে হবে
# result : []
# line:
#  25/11/23, 8:19 pm - +91 82509 91152: IMG-20231125-WA0006.jpg (file attached)
# result : []
# line:
#  Sobai 29 tarik modha taka jama korba
# result : []
# line:
#  25/11/23, 8:48 pm - Lob: Bill ta send Kore de
# result : []
# line:
#  25/11/23, 8:49 pm - +91 82509 91152: IMG-20231125-WA0007.jpg (file attached)
# result : []
# line:
#  27/11/23, 7:43 pm - +91 78110 67881: AJ k ke ranna ghor theke macher matha oo macher tel kheyecho janio.....
# result : []
# line:
#  27/11/23, 10:16 pm - Susovan (Mess: Je khiache amake personal bhabe massage kore janaw ami sei bektike katla macher matha bheje khawabo. Erokom bhabe khawar dorkar thake niii. Ajke ratri menu te detam aita.
# result : []
# line:
#  29/11/23, 7:48 am - +91 78110 67881: কাকিমা আসবেনা -
# result : []
# line:
#  বুধবার সকাল গ্রুপ 4 (মনি শংকর, সুশোভন, মনোজ, রঞ্জিত )
# result : []
# line:
#
# result : []
# line:
#  রান্না করতে হবে
# result : []
# line:
#  29/11/23, 10:31 pm - +91 82509 91152: Taka jama Koro sobai
# result : []
# line:
#  30/11/23, 9:11 am - +91 78110 67881: রাতে কারো মিল বন্ধ বা চালু করতে 11.00 Am মধ্যে জানাবে। হিসাব নিকাশ করতে হবে
# result : []
# line:
#  30/11/23, 10:00 am - +91 76027 79174: Amr mil off tak  be cont...Niru Mandi
# result : []
# line:
#  30/11/23, 4:38 pm - JOYPRAKASH MAHATA: Ratay meal hobay
# result : []
# line:
#  30/11/23, 5:02 pm - +91 78110 67881: আজ 10.20pm সময় ম্যানেজার রুমে নভেম্বর মাসের হিসাব নিকাশ সংক্রান্ত মিটিং হবে।
# result : []
# line:
#  01/12/23, 7:59 am - +91 832 874 4399: *দুপুরের ও রাতের জন্য মিল চালু বা বন্ধ করতে হলে রাত 10 টা ও বিকাল 5 টার মধ্যে জানতে হবে ।।*
# result : []
# line:
#
# result : []
# line:
#  ইতি,
# result : []
# line:
#  Manager
# result : []
# line:
#  01/12/23, 10:38 am - +91 78110 67881: IMG-20231201-WA0000.jpg (file attached)
# result : []
# line:
#  সবাই 5 তারিখের মধ্যে টাকা মিটিয়ে দিবে
# result : []
# line:
#  01/12/23, 10:40 am - +91 78110 67881 updated the message timer. New messages will disappear from this chat 90 days after they're sent, except when kept.
# result : []
# line:
#  01/12/23, 10:40 am - +91 78110 67881 turned off disappearing messages.
# result : []
# line:
#  01/12/23, 11:12 am - Lob: Paid
# result : []
# line:
#  03/12/23, 2:33 pm - Sandip Maity Mess Sadhana: Ajj night theke amar meal continue on hobe....
# result : []
# line:
#  *_Sandip_*
# result : []
# line:
#  03/12/23, 5:42 pm - Ranjit Mess Sadhana: Aj night a meal hobe.....
# result : []
# line:
#
# result : []
# line:
#  Ranjit Roy
# result : []
# line:
#  04/12/23, 4:44 pm - +91 99335 77215: Night e meal off thakbe.....morning e abar meal continue hbe(praaenjit)
# result : []
# line:
#  05/12/23, 10:32 pm - +91 832 874 4399: IMG-20231205-WA0002.jpg (file attached)
# result : []
# line:
#  05/12/23, 10:32 pm - +91 832 874 4399: Aj keo macher matha churi geche......
# result : []
# line:
#  06/12/23, 3:51 pm - Lob: IMG-20231206-WA0002.jpg (file attached)
# result : []
# line:
#  06/12/23, 11:01 pm - +91 832 874 4399: Kalke bazar korte keu icchuk noi .....amar o  somoy hobe na tai kal ke ki kora hobe bolo sobai
# result : []
# line:
#  06/12/23, 11:01 pm - +91 832 874 4399: Manager
# result : []
# line:
#  07/12/23, 10:50 am - Ranjit Mess Sadhana: আজকে রুই মাছ নিয়ে আসছি, মাছের মাথা যেখানে থাকে সেখানেই রয়েছে।
# result : []
# line:
#  I reminded
# result : []
# line:
#  07/12/23, 2:42 pm - +91 832 874 4399: আজ রাত্রে খিচুড়ি হবে, কেউ যদি রান্না করতে ইচ্ছুক হও তাহলে হবে, নাহলে হবেনা.....
# result : []
# line:
#
# result : []
# line:
#  Manager
# result : []
# line:
#  07/12/23, 5:17 pm - +91 832 874 4399: এই প্রস্তাবটি বিশেষ কারণে আর হচ্ছে না।।
# result : []
# line:
#
# result : []
# line:
#
# result : []
# line:
#
# result : []
# line:
#  ইতি,
# result : []
# line:
#  Manager
# result : []
# line:
#  07/12/23, 5:18 pm - Susovan (Mess: Keno??
# result : []
# line:
#  07/12/23, 5:25 pm - +91 80012 92291: Ranna karer keo nai.
# result : []
# line:
#  07/12/23, 5:27 pm - Susovan (Mess: Sobai mile too hoia jetoo ranna. Ami jani kechuri korte . Kakima ki asbe naaa.?
# result : []
# line:
#  07/12/23, 5:28 pm - +91 80012 92291: Asbe.
# result : []
# line:
#  07/12/23, 5:29 pm - Susovan (Mess: Ta holee kakima thakle Ami help kore ditam ar 2 ekjon thakle hoia jabe
# result : []
# line:
#  07/12/23, 5:39 pm - +91 82509 91152: খিচুড়ি হলে আমার মিল off thakba
# result : []
# line:
#  07/12/23, 6:31 pm - +91 832 874 4399: আজ খিচুড়ি হচ্ছে
# result : []
# line:
#  07/12/23, 10:25 pm - Lob: Sudhumatra kal sokaler meal off thak be... Rate hobe 👍
# result : []
# line:
#  11/12/23, 6:47 pm - Ranjit Mess Sadhana: IMG-20231211-WA0000.jpg (file attached)
# result : []
# line:
#  Dekte Dekte abr chole aslo....
# result : []
# line:
#  13/12/23, 6:42 pm - Susovan (Mess: Aj ratri theke meal off thakbe susovan.
# result : []
# line:
#  14/12/23, 12:33 pm - +91 832 874 4399: Jodi aj rate kakima na ase to grp 5 ranna korbe ...
# result : []
# line:
#
# result : []
# line:
#  Manager
# result : []
# line:
#  14/12/23, 12:34 pm - +91 832 874 4399: IMG-20231214-WA0000.jpg (file attached)
# result : []
# line:
#  14/12/23, 12:45 pm - Lob: Aj rat theke continue meal off thak be...
# result : []
# line:
#  14/12/23, 6:38 pm - +91 832 874 4399: Kakima aschena confirm
# result : []
# line:
#  14/12/23, 6:38 pm - +91 832 874 4399: Kal sokale grp 2 ratre grp 1 ranna korbe
# result : []
# line:
#  15/12/23, 6:01 pm - +91 832 874 4399: Kalkeo kakima asbe na
# result : []
# line:
#  15/12/23, 9:58 pm - +91 832 874 4399: Kal sokale grp 4 r rate grp 3 ranna korbe...
# result : []
# line:
#  16/12/23, 1:42 pm - Lob: Rat theke meal on hobe 👍
# result : []
# line:
#  16/12/23, 3:50 pm - +91 832 874 4399: Aj rate grp 5 ranna korbe ...kal sokale grp 3 ranna korbe
# result : []
# line:
#  16/12/23, 4:55 pm - Saikat: This message was deleted
# result : []
# line:
#  16/12/23, 10:09 pm - Tapas Pradhan: Kal sokale & rate meal off thakbe
# result : []
# line:
#  16/12/23, 10:09 pm - Tapas Pradhan: Monday sokale meal hobe
# result : []
# line:
#  17/12/23, 3:01 pm - Purna(mess-mid: বিকেলে কাকিমার বাড়িতে যাব। কাকিমার অসুস্থতার কারণে ম্যানেজার সিপ থেকে ৫০০ টাকা দেওয়া হবে। সবার মতামত জানাও....
# result : []
# line:
#  17/12/23, 3:14 pm - Sasti: Akdom 👍
# result : []
# line:
#  17/12/23, 3:46 pm - Lob: Taka dao.. 500 rr akta Biscuit packet oo niye jaya hok
# result : []
# line:
#  17/12/23, 4:13 pm - Purna(mess-mid: Bakira bolo....
# result : []
# line:
#  17/12/23, 4:34 pm - Purna(mess-mid: Tahole karor kono problem nai to...
# result : []
# line:
#  17/12/23, 10:07 pm - +91 832 874 4399: Kal sokale grp 2 rate grp 4 ranna korbe
# result : []
# line:
#  18/12/23, 8:00 pm - +91 832 874 4399: This message was deleted
# result : []
# line:
#  18/12/23, 8:08 pm - Purna(mess-mid: রান্নার কাকিমাকে কল করতে  কাকিমা বললেন  তার পায়ের  হাড় ভেঙে গেছে , তাই কাকিমা এখন 1-2 মাস আসতে পারবেন না। তাই কাকিমা বলেছেন নতুন কাকিমা ঠিক করতে। আবার সুস্থ হলে রান্না করতে আসবেন।
# result : []
# line:
#  18/12/23, 10:03 pm - +91 832 874 4399: This message was deleted
# result : []
# line:
#  18/12/23, 10:03 pm - +91 832 874 4399: Kal Sokale 3no r rate 5 no ranna korbe
# result : []
# line:
#  19/12/23, 12:20 pm - Ranjit Mess Sadhana: IMG-20231219-WA0000.jpg (file attached)
# result : []
# line:
#  K K jabe
# result : []
# line:
#  19/12/23, 5:20 pm - Saikat: Soňdhar meal off hobe
# result : []
# line:
#  sokal thake meal hobe
# result : []
# line:
#  saikat
# result : []
# line:
#  19/12/23, 10:05 pm - +91 82509 91152: Kal sokal meal 📴 thakba
# result : []
# line:
#  SUBHAJIT
# result : []
# line:
#  20/12/23, 3:32 pm - +91 82509 91152: Rate meal 📴 thakba.... Subhajit
# result : []
# line:
#  20/12/23, 8:30 pm - Susovan (Mess: Kall sokal theke meal on hobe susovan.
# result : []
# line:
#  21/12/23, 2:58 pm - Lob: <Media omitted>
# result : []
# line:
#  21/12/23, 5:02 pm - Susovan (Mess: Aj ratri te meal off thakbe kall sokal a meal hobe susovan
# result : []
# line:
#  21/12/23, 10:13 pm - Tapas Pradhan: Kal sokale & rate meal off thakbe,
# result : []
# line:
#  Saturday sokake hobe
# result : []
# line:
#  24/12/23, 6:58 pm - +91 832 874 4399: Kal ke ki mangsho hobe ???...managership e taka nai mangsho korar moto
# result : []
# line:
#  24/12/23, 6:58 pm - +91 832 874 4399: Manager
# result : []
# line:
#  25/12/23, 8:43 am - +91 74072 29043: IMG-20231225-WA0005.jpg (file attached)
# result : []
# line:
#  Fund balance
# result : []
# line:
#  25/12/23, 8:56 am - +91 832 874 4399: Aj sokale mangsho hochhe
# result : []
# line:
#  25/12/23, 1:03 pm - +91 832 874 4399: Ajker mangsher jonno 30 taka kore chanda
# result : []
# line:
#  25/12/23, 4:41 pm - Tapas Pradhan: Rate meal off thakbe
# result : []
# line:
#  25/12/23, 4:42 pm - Tapas Pradhan: Sokale hobe
# result : []
# line:
#  25/12/23, 10:52 pm - Saikat: Kal sokal theke meal off thakbe
# result : []
# line:
#  saikať
# result : []
# line:
#  26/12/23, 6:31 pm - +91 832 874 4399: Jara taka daoni tader khata re minus kore dichhi
# result : []
# line:
#  27/12/23, 4:04 pm - Susovan (Mess: Rat theke meal off thakbe
# result : []
# line:
#  27/12/23, 5:17 pm - Susovan (Mess: Susovan
# result : []
# line:
#  28/12/23, 7:23 pm - +91 832 874 4399: Jara 1000 taka joma koroni taratari joma koro.......
# result : []
# line:
#
# result : []
# line:
#  Manager
# result : []
# line:
#  29/12/23, 11:34 am - Lob: IMG-20231229-WA0000.jpg (file attached)
# result : []
# line:
#  29/12/23, 3:19 pm - Saikat: Rate meal on hobe
# result : []
# line:
#  SAIKAT
# result : []
# line:
#  29/12/23, 10:28 pm - JOYPRAKASH MAHATA: Kal sokal a meal 📴 hobay
# result : []
# line:
#  30/12/23, 11:30 am - +91 74072 29043: IMG-20231230-WA0000.jpg (file attached)
# result : []
# line:
#  30/12/23, 3:07 pm - +91 74072 29043: IMG-20231230-WA0001.jpg (file attached)
# result : []
# line:
#  Managership details
# result : []
# line:
#  31/12/23, 9:06 am - +91 832 874 4399: Ratre meal bondho ba chalu korar jonno 11 tar modhe janao
# result : []
# line:
#  31/12/23, 9:46 am - +91 832 874 4399: *sokal 11 ta <This message was edited>
# result : []
# line:
#  31/12/23, 11:49 am - +91 832 874 4399: Managership theke ajke magsho hobe
# result : []
# line:
#  31/12/23, 11:50 am - +91 832 874 4399: Ratre
# result : []
# line:
#  31/12/23, 5:27 pm - +91 832 874 4399: Aj rat 10 tay niru mandir room e December maser managership meeting hobe
# result : []
# line:
#  31/12/23, 7:07 pm - +91 74072 29043: IMG-20231231-WA0000.jpg (file attached)
# result : []
# line:
#  Fund balance Rs 2868.   Rs500 is still due from Niru Mandi as Entrance fees.
# result : []
# line:
#  31/12/23, 11:58 pm - +91 832 874 4399: IMG-20231231-WA0001.jpg (file attached)
# result : []
# line:
#  5 tarik er modhhe taka dao
# result : []
# line:
#  01/01/24, 12:04 am - Tapas Pradhan: IMG-20231231-WA0003.jpg (file attached)
# result : []
# line:
#  01/01/24, 12:26 am - +91 99335 77215: Happy new year 2024
# result : []
# line:
#  01/01/24, 12:50 am - Purna(mess-mid: VID-20240101-WA0005.mp4 (file attached)
# result : []
# line:
#  01/01/24, 6:16 am - Lob: Happy new year..... 2024
# result : []
# line:
#  January maser managership ti ami dekha suna korchi.....(ati Asish dar managership )  Tai sobai nirdisto time er modhya taka diye, bazar er nam likhe amake sahajjo korbe... Thanking you 🥰 <This message was edited>
# result : []
# line:
#  01/01/24, 2:56 pm - +91 76027 79174: Sudu ajk Ratre mil off tak be Niru Mandi 🙏👍
# result : []
# line:
#  01/01/24, 5:25 pm - +91 832 874 4399: Ajke rate meal off thakbe kal sokal theke abar meal chalu hobe.....subhadip
# result : []
# line:
#  01/01/24, 5:27 pm - +91 78110 67881: Aj ratri te meal off thakbe kall sokal a meal hobe.... Sudip
# result : []
# line:
#  01/01/24, 11:22 pm - Susovan (Mess: Kall sokal a meal hobe susovan
# result : []
# line:
#  01/01/24, 11:35 pm - Prabin Pramanik: Mr. Sobee Maya.... meal will counted from tomorrow morning 😌😌😌
# result : []
# line:
#  01/01/24, 11:37 pm - Susovan (Mess: Dekho jodi hoi meal taaa khub bhalo hoi
# result : []
# line:
#  02/01/24, 10:33 am - Lob: 👉👉👉
# result : []
# line:
#  02/01/24, 10:33 am - Lob: Sobai Taka joma koro.... Bazarer nam likhe dao
# result : []
# line:
#  02/01/24, 4:44 pm - +91 99335 77215: Night e amar meal 📴 thakbe....morning e abar meal habe..(prasenjit)
# result : []
# line:
#  02/01/24, 5:23 pm - Tapas Pradhan: Rate meal off thakbe
# result : []
# line:
#  02/01/24, 5:23 pm - Tapas Pradhan: Sokale hobe
# result : []
# line:
#  05/01/24, 7:24 am - +91 832 874 4399: Reminder
# result : []
# line:
#  05/01/24, 7:43 pm - +91 832 874 4399: Kalke amar meal bondho thakbe, sunday sokal theke abar chalu hobe .....subhadip
# result : []
# line:
#  05/01/24, 7:44 pm - +91 832 874 4399: Jara jara taka daoni taratari dao ..aj 5 tarik
# result : []
# line:
#  05/01/24, 10:02 pm - Lob: Sobai 15 taka Kore Monoj Kumar K diye debe..... 1st January er  kharach babad....jader meal chole chilo ........Thanking you <This message was edited>
# result : []
# line:
#  06/01/24, 2:55 pm - Tapas Pradhan: Rat thake meal off thakbe
# result : []
# line:
#  06/01/24, 3:45 pm - Ranjit Mess Sadhana: Rat theke meal off thakbe
# result : []
# line:
#  06/01/24, 3:45 pm - Ranjit Mess Sadhana: Ranjit Roy
# result : []
# line:
#  07/01/24, 9:08 am - +91 832 874 4399: Niru, Ranjit da, Sasthi da tomader taka due ache ager managership e ....taka dao taratari
# result : []
# line:
#  07/01/24, 7:42 pm - +91 82509 91152: IMG-20240107-WA0001.jpg (file attached)
# result : []
# line:
#  07/01/24, 10:15 pm - Tapas Pradhan: Kal sokale meal hobe
# result : []
# line:
# ...
# result : []
# line:
#  15/01/24, 9:11 pm - Saikat: kal sokal theke continue meal off thakbe
# result : []
# line:
#  17/01/24, 4:18 pm - Subhankar(mess: Aj night meal hobe
# result : []
# line:
#
# result : []
# line:
#  Subhankar Ghorai
# result : []
# line:
#  Sandip Maity
# result : []
# line:
#  17/01/24, 4:25 pm - +91 82509 91152: Rate thaka meal 📴 thakba continue
# result : []
# line:
#  17/01/24, 4:40 pm - Saikat: আজ সন্ধ্যা থেকে আমার মিল অন হবে
# result : []
# line:
#  সৈকত
# result : []
# line:
#  18/01/24, 11:49 am - Lob: IMG-20240118-WA0003.jpg (file attached)
# result : []
# line:
#  *মাদ্রাসা সার্ভিস কমিশনের শিক্ষক নিয়োগ পরীক্ষা  ২৮শে জানুয়ারি,*
# result : []
# line:
#  18/01/24, 1:24 pm - Lob: Jara 1000 Kore daoni tara taka dao nahole kal bazar hobe na
# result : []
# line:
#  19/01/24, 1:37 pm - Monisankar Pradhan Mess: রাত থেকে আমার মিল চালু হবে- মনিশংকর
# result : []
# line:
#  20/01/24, 9:25 pm - +91 76027 79174: Kal sokal theke continue mil on hbe.... Niru Mandi 🙏👍
# result : []
# line:
#  20/01/24, 10:51 pm - +91 82509 91152: Kal sokal thaka continue meal 📴 thakba...
# result : []
# line:
#  21/01/24, 2:31 pm - Saikat: IMG-20240121-WA0000.jpg (file attached)
# result : []
# line:
#  21/01/24, 2:31 pm - Saikat: IMG-20240121-WA0001.jpg (file attached)
# result : []
# line:
#  21/01/24, 10:29 pm - Lob: Sokale Kakima na asle... Group 1 ranna korbe 👍
# result : []
# line:
#  21/01/24, 10:29 pm - Susovan (Mess: Kall sokal theke amar meal off thakbe Susovan.
# result : []
# line:
#  21/01/24, 10:30 pm - Lob: 👈
# result : []
# line:
#  24/01/24, 12:24 pm - +91 76027 79174: Ratre teke continue mil off tak be...Niru Mandi 🙏👍
# result : []
# line:
#  24/01/24, 2:16 pm - Lob: IMG-20240124-WA0003.jpg (file attached)
# result : []
# line:
#  25/01/24, 11:24 am - Lob: IMG-20240125-WA0000.jpg (file attached)
# result : []
# line:
#  25/01/24, 11:29 am - Ranjit Mess Sadhana: Chele gulo r man samman ta rakhlo na.....loker ka6e kotha sunte ho66e e gulo ki ho66e.... Metting hok.......
# result : []
# line:
#  25/01/24, 3:03 pm - +91 82509 91152: IMG-20240125-WA0001.jpg (file attached)
# result : []
# line:
#  এইটা ডাব চুরি করার যন্ত্র ।কালকে মেসে ডাব চুরি করতে চোর এসেছিল। সবাই সাবধানে থেকো। এই চোরকে আমার মনে হয় নোবেল দেওয়া উচিত।
# result : []
# line:
#  26/01/24, 7:47 pm - Lob: Kakimar sarir kharap ranna korte korte chole gechen Aj....
# result : []
# line:
#  Jodie kal sokale aste na paren tahole group 1 ranna korbe
# result : []
# line:
#  26/01/24, 7:49 pm - Lob: IMG-20240114-WA0000.jpg (file attached)
# result : []
# line:
#  26/01/24, 10:28 pm - Tapas Pradhan: Kal sokal thake meal off thakbe
# result : []
# line:
#  28/01/24, 9:27 am - +91 74072 29043: <Media omitted>
# result : []
# line:
#  Managership details
# result : []
# line:
#  28/01/24, 1:03 pm - Subhankar(mess: Ajke night meal hobe.
# result : []
# line:
#  Subhankar
# result : []
# line:
#  28/01/24, 1:06 pm - Sandip Maity Mess Sadhana: Ajj night theke amar meal continue hobe
# result : []
# line:
#  *_Sandip_*
# result : []
# line:
#  28/01/24, 5:16 pm - +91 76027 79174: Mil on hbe continue.... Niru Mandi 🙏👍
# result : []
# line:
#  28/01/24, 10:11 pm - Tapas Pradhan: Kal sokal thake meal hobe
# result : []
# line:
#  29/01/24, 10:20 pm - Saikat: আগামীকাল সকাল থেকে মিল বন্ধ থাকিবে।
# result : []
# line:
#  30/01/24, 11:21 am - Lob: Kal maser ses... Abong Wednesday........ Tai extra  kichu menu hobe... Jodi Karo problem thake janio... Aj sandhyar modhya. 👍
# result : []
# line:
#  30/01/24, 11:54 pm - Susovan (Mess: Kall sokal theke meal hobe susovan
# result : []
# line:
#  31/01/24, 7:11 am - Lob: Aj rate karo meal off ba on hole.... 10.30am modhya janioo ......hisab korbo tai.....
# result : []
# line:
#  31/01/24, 8:48 am - Saikat: রাতে মিল হবে
# result : []
# line:
#  সৈকত
# result : []
# line:
#  31/01/24, 10:50 am - Lob: Aj launch er menu te thakche....
# result : []
# line:
#  1. 5cha ratna
# result : []
# line:
#  2. Kabli - soyabin
# result : []
# line:
#  3. Chatni
# result : []
# line:
#  4. Begun vaja 1pic
# result : []
# line:
#  Thanks
# result : []
# line:
#  31/01/24, 12:54 pm - Lob: Aj rate January maser meeting hobe... saikat /Subhajit ....er room aa
# result : []
# line:
#  Time 10.30pm👍 <This message was edited>
# result : []
# line:
#  31/01/24, 10:16 pm - Purna(mess-mid: IMG-20240131-WA0009.jpg (file attached)
# result : []
# line:
#  31/01/24, 11:49 pm - +91 74072 29043: IMG-20240131-WA0010.jpg (file attached)
# result : []
# line:
#  Fund balance : Rs 2932
# result : []
# line:
#  01/02/24, 12:16 am - Lob: IMG-20240201-WA0001.jpg (file attached)
# result : []
# line:
#  5 tariker modhya sobai paid korbe..... 👍👍
# result : []
# line:
#  02/02/24, 11:20 am - Lob: Taka dao
# result : []
# line:
#  02/02/24, 7:35 pm - +91 832 874 4399: Kal sokale amar meal off hobe rate abar meal chalu hobe...subhadip
# result : []
# line:
#  02/02/24, 10:28 pm - Tapas Pradhan: Kal sokal thake meal off thakbe
# result : []
# line:
#  03/02/24, 9:49 am - Lob: This message was deleted
# result : []
# line:
#  03/02/24, 9:51 am - Lob: IMG-20240203-WA0001.jpg (file attached)
# result : []
# line:
#  03/02/24, 12:50 pm - Lob: 👍
# result : []
# line:
#  03/02/24, 9:53 pm - +91 82509 91152: Kal sokal thaka continue meal 📴 thakba.... Subhajit
# result : []
# line:
#  03/02/24, 10:21 pm - Subhankar(mess: POLL:
# result : []
# line:
#  Kal sakale meat hobe ?
# result : []
# line:
#  OPTION: Yes (13 votes)
# result : []
# line:
#  OPTION: No (1 vote)
# result : []
# line:
#
# result : []
# line:
#  03/02/24, 10:41 pm - Lob: This message was deleted
# result : []
# line:
#  04/02/24, 7:54 am - Subhankar(mess: Meat hobe aj sakale
# result : []
# line:
#  04/02/24, 10:02 am - Lob: Jara baki acho send kore dio 👍👍
# result : []
# line:
#  04/02/24, 3:23 pm - Lob: Manager akta massage koro meeting er bepare
# result : []
# line:
#  04/02/24, 8:53 pm - Subhankar(mess: Jader sokal e meal hoyachilo Tara 10taka dibe....
# result : []
# line:
#  04/02/24, 9:11 pm - Lob: Already done
# result : []
# line:
#  04/02/24, 10:14 pm - Tapas Pradhan: Kal sokale meal hobe
# result : []
# line:
#  06/02/24, 9:57 pm - Prabin Pramanik: Dear Manager....
# result : []
# line:
#  Meal stoped only tomorrow morning and continue meal start from night.......
# result : []
# line:
#  Prabin <This message was edited>
# result : []
# line:
#  06/02/24, 10:04 pm - Sasti: Dear Manager....
# result : []
# line:
#  Meal stoped only tomorrow morning and continue meal start from night.......
# result : []
# line:
#  sosthi🤟
# result : []
# line:
#  06/02/24, 10:07 pm - Prabin Pramanik: You have to follow the plagiarism, this is very bad....😁😁😁😁
# result : []
# line:
#  06/02/24, 10:09 pm - Sasti: You have to follow the plagiarism, this is very bad....😁😁😁😁
# result : []
# line:
#  07/02/24, 2:47 pm - Monisankar Pradhan Mess: রাত থেকে আমার মিল চালু হবে- মনিশংকর
# result : []
# line:
#  09/02/24, 5:19 pm - JOYPRAKASH MAHATA: Ratay meal hobay
# result : []
# line:
#  10/02/24, 4:51 pm - Monisankar Pradhan Mess: রাত থেকে আমার মিল বন্ধ থাকবে - মনিশংকর
# result : []
# line:
#  10/02/24, 4:55 pm - Prabin Pramanik: Dear Manager....
# result : []
# line:
#  Continue meal stop from tonight..
# result : []
# line:
#  10/02/24, 9:05 pm - Purna(mess-mid: *_The Honorable Boarders present at the Mess are hereby informed that as per the date fixed in the said meeting, it is requested to deposit the prescribed puja subscription with the treasurer by tomorrow_*
# result : []
# line:
#  ..........By Purna &  Saikat
# result : []
# line:
#  11/02/24, 6:20 pm - Lob: Kal tahole dupure manso hochhe too??
# result : []
# line:
#  11/02/24, 6:48 pm - +91 80012 92291: Hok.
# result : []
# line:
#  11/02/24, 6:49 pm - +91 76027 79174: Hok .....Niru Mandi 🙏👍
# result : []
# line:
#  11/02/24, 7:11 pm - JOYPRAKASH MAHATA: হোক
# result : []
# line:
#  11/02/24, 7:15 pm - Sasti: This message was deleted
# result : []
# line:
#  11/02/24, 7:16 pm - Sasti: Eyyyyyyyyyyyyy hok🤸
# result : []
# line:
#  11/02/24, 7:20 pm - Ranjit Mess Sadhana: Hok hok
# result : []
# line:
#  11/02/24, 7:29 pm - +91 832 874 4399: Hok
# result : []
# line:
#  11/02/24, 7:37 pm - Prabin Pramanik: Plz avoid this day, because I'm not present here.
# result : []
# line:
#  11/02/24, 8:00 pm - Lob: Var papto manager..... Tahole kal Wednesday er meat ta korbe too???
# result : []
# line:
#  Karan sedin to Puja..... Rrr problem thakle bolo
# result : []
# line:
#  11/02/24, 10:26 pm - Saikat: বুধবার পুজোর কারণে ওই দিনের মাংসটা যদি আগামীকাল সকাল বেলা করা হয় যারা উপস্থিত নেই তারা সকলে জানাও কোন আপত্তি আছে কিনা?
# result : []
# line:
#  সকাল ৭ টার মধ্যে
# result : []
# line:
#  প্রবীণ বাদে কারো আপত্তি থাকলে জানাও কারণ সে পরে জানিয়েছে লবদা কে তার কোন আপত্তি নেই।
# result : []
# line:
#  12/02/24, 12:53 am - +91 99335 77215: হোক কাল চিকেন
# result : []
# line:
#  12/02/24, 3:38 pm - Lob: IMG-20240212-WA0000.jpg (file attached)
# result : []
# line:
#  12/02/24, 3:53 pm - Lob: IMG-20240212-WA0001.jpg (file attached)
# result : []
# line:
#  12/02/24, 3:59 pm - Lob added +91 73195 35266
# result : []
# line:
#  12/02/24, 4:01 pm - +91 73195 35266: Ami Amiya
# result : []
# line:
#  12/02/24, 4:26 pm - Susovan (Mess: Baje kotha bhai sob bujhung bhajung
# result : []
# line:
#  12/02/24, 4:26 pm - Lob: 😃😁
# result : []
# line:
#  12/02/24, 4:26 pm - Susovan (Mess: Chall churi kora taka ta debe mone hoiii
# result : []
# line:
#  12/02/24, 4:27 pm - Lob: 😁😁Tui Kobe asbi mess
# result : []
# line:
#  12/02/24, 4:27 pm - Susovan (Mess: Jabo naaa ekhane job peye gachii.
# result : []
# line:
#  12/02/24, 4:28 pm - Lob: Congratulations bro 🥰
# result : []
# line:
#  12/02/24, 6:36 pm - Lob: Requested to all mess member,  we are celebrating to "saraswati Puja".  So, please all candidate participate this puja festival (14/02/2024).
# result : ['14/02/2024']
# startsWithDateAndTime :
#  <function startsWithDateAndTime at 0x0000019DE0CD4790>
# line:
#
# result : []
# line:
#  Thanking you 🥰🥰
# result : []
# line:
#  12/02/24, 10:32 pm - Prabin Pramanik: Dear Manager....
# result : []
# line:
#  The meal will continue started from tomorrow morning..
# result : []
# line:
#  ....Prabin....
# result : []
# line:
#  13/02/24, 2:10 pm - +91 76027 79174: Continue mil off tak be.....Niru Mandi 🙏👍
# result : []
# line:
#  13/02/24, 5:46 pm - +91 99335 77215: Meal habe amar night theke....prasenjit
# result : []
# line:
#  14/02/24, 12:01 am - +91 73195 35266: IMG-20240214-WA0000.jpg (file attached)
# result : []
# line:
#  14/02/24, 12:15 am - Ranjit Mess Sadhana: IMG-20240214-WA0001.jpg (file attached)
# result : []
# line:
#  14/02/24, 12:16 am - Ranjit Mess Sadhana: IMG-20240214-WA0002.jpg (file attached)
# result : []
# line:
#  14/02/24, 3:16 pm - +91 73195 35266: Amar meal AJ ratri theke off thakbe(Amiya)
# result : []
# line:
#  14/02/24, 9:41 pm - +91 832 874 4399: Kal sokal theke amar meal off thakbe ......subhadip
# result : []
# line:
#  14/02/24, 9:50 pm - Ranjit Mess Sadhana: IMG-20240214-WA0005.jpg (file attached)
# result : []
# line:
#  14/02/24, 9:50 pm - Ranjit Mess Sadhana: IMG-20240214-WA0006.jpg (file attached)
# result : []
# line:
#  14/02/24, 9:50 pm - Ranjit Mess Sadhana: IMG-20240214-WA0007.jpg (file attached)
# result : []
# line:
#  14/02/24, 9:50 pm - Ranjit Mess Sadhana: IMG-20240214-WA0008.jpg (file attached)
# result : []
# line:
#  14/02/24, 10:02 pm - Saikat: আগামীকাল মেসে আছো অথচ  মিল হবে না যদি এরকম কেউ থাকো জানাও।
# result : []
# line:
#  আর যদি মেসে নেই অথচ মিল হবে সেটাও জানিয়ে দাও। <This message was edited>
# result : []
# line:
#  14/02/24, 10:07 pm - +91 82509 91152: Kal morning theke meal hoba... SUBHAJIT
# result : []
# line:
#  15/02/24, 6:29 am - Saikat: আজ সকালে কাকিমা আসবেনি  এক নম্বর গ্রুপ সন্দীপ  তাপস দা পূর্ণ সুদীপের রান্না আছে
# result : []
# line:
#  16/02/24, 6:07 am - +91 73195 35266: AJ sakale amar meal habe (Amiya)
# result : []
# line:
#  16/02/24, 7:19 am - +91 73195 35266: Ami bus paini  amar meal ta ki off Kara jabe tahole 📴 kore dio.
# result : []
# line:
#  16/02/24, 7:46 am - Saikat: Ok
# result : []
# line:
#  16/02/24, 1:03 pm - Saikat: আগামীকাল সন্ধ্যেবেলায়  সরস্বতী পুজো সংক্রান্ত ফিস্ট হচ্ছে তাই সকলে চেষ্টা করবে থাকার জন্য।
# result : []
# line:
#  16/02/24, 5:31 pm - Susovan (Mess: Fest ta porsu korle hoto naa ?? Karon ami porsu firchi.
# result : []
# line:
#  16/02/24, 5:37 pm - Lob: This message was deleted
# result : []
# line:
#  16/02/24, 5:59 pm - Ranjit Mess Sadhana: সহমত
# result : []
# line:
#  16/02/24, 6:00 pm - Lob: This message was deleted
# result : []
# line:
#  16/02/24, 6:05 pm - +91 99335 77215: Tahle 20 ফেব্রুয়ারি হোক না...এটা আমার মত.
# result : []
# line:
#  16/02/24, 6:43 pm - Susovan (Mess: Haaa karon aii year ami puja dekha amar kopal a hoini taii tomader sathe anando ta bhag korte chai. Karo kichu apotti thakle osubidha nai.
# result : []
# line:
#  16/02/24, 8:28 pm - Subhankar(mess: সহমত
# result : []
# line:
#  16/02/24, 10:15 pm - +91 73195 35266: Kal sakal theke amar meal on  habe
# result : []
# line:
#  16/02/24, 10:25 pm - +91 80012 92291: Amaro sahamat
# result : []
# line:
#  16/02/24, 10:29 pm - JOYPRAKASH MAHATA: Fest bondho koro ja taka a6ay sobai vag koray now
# result : []
# line:
#  16/02/24, 10:31 pm - Prabin Pramanik: The date was fixed after discussions at all levels.  So this date cannot be changed in any way.  The talking point is that everyone was invited on Saturday. So we're helpless.
# result : []
# line:
#  Thank You
# result : []
# line:
#  16/02/24, 10:31 pm - Lob: Date ta Kora hoyechee jehetu kal keii hobe
# result : []
# line:
#  Tor sathe sobai mile pore Kore neboo... Amra too thakchi
# result : []
# line:
#  16/02/24, 10:46 pm - Tapas Pradhan: Kal sokal thake meal off thakbe
# result : []
# line:
#  17/02/24, 4:50 pm - +91 76027 79174: Continue mil on hbe...Niru Mandi 🙏👍
# result : []
# line:
#  17/02/24, 4:55 pm - Tapas Pradhan: Rate meal hobe
# result : []
# line:
#  17/02/24, 7:10 pm - Ranjit Mess Sadhana: IMG-20240217-WA0000.jpg (file attached)
# result : []
# line:
#  17/02/24, 7:10 pm - Ranjit Mess Sadhana: IMG-20240217-WA0001.jpg (file attached)
# result : []
# line:
#  17/02/24, 7:11 pm - Lob: 🥰
# result : []
# line:
#  17/02/24, 10:02 pm - Ranjit Mess Sadhana: IMG-20240217-WA0002.jpg (file attached)
# result : []
# line:
#  17/02/24, 10:02 pm - Ranjit Mess Sadhana: IMG-20240217-WA0003.jpg (file attached)
# result : []
# line:
#  18/02/24, 12:01 am - Soumitra (Mid Mess added +91 832 874 4399
# result : []
# line:
#  18/02/24, 10:27 am - +91 74072 29043: IMG-20240218-WA0000.jpg (file attached)
# result : []
# line:
#  18/02/24, 3:30 pm - Susovan (Mess: Amar meal hobe raatri theke ar ekta guest meal hobee kemon.
# result : []
# line:
#  18/02/24, 7:16 pm - Saikat: আজকের রাত্রি দশটা পনেরোতে সরস্বতী পুজো সংক্রান্ত হিসাবের মিটিং হবে আমার রুমে সবাইকে অনুরোধ মিটিং-এ যোগদান করার জন্য।
# result : []
# line:
#  18/02/24, 10:47 pm - +91 74072 29043: IMG-20240218-WA0001.jpg (file attached)
# result : []
# line:
#  19/02/24, 9:58 am - Subhankar(mess: কাল সকালেই রান্নার কাকিমা আসবে না
# result : []
# line:
#  সকালে গ্রুপ -১
# result : []
# line:
#  রাতে গ্রুপ-২
# result : []
# line:
#  রান্না করবে
# result : []
# line:
#  19/02/24, 10:11 pm - +91 78110 67881: This message was deleted
# result : []
# line:
#  19/02/24, 10:23 pm - +91 78110 67881: Kal sokal thake amer meal continue off thakbe.   Sudip sing
# result : []
# line:
#  23/02/24, 8:02 pm - +91 78110 67881: Kal sokal theke continue meal on hobe.
# result : []
# line:
#  Sudip sing
# result : []
# line:
#  23/02/24, 9:17 pm - Soumitra (Mid Mess changed this group's icon
# result : []
# line:
#  24/02/24, 12:25 pm - +91 99335 77215: IMG-20240224-WA0000.jpg (file attached)
# result : []
# line:
#  Dear ম্যানেজার আমাকে এই টাকাটা দেবেন,,,
# result : []
# line:
#  24/02/24, 5:04 pm - +91 80012 92291: Aj Rat theke  Joyprakash Mahata er meal on hbe.
# result : []
# line:
#  24/02/24, 5:34 pm - +91 832 874 4399: Aj rate amar meal off thakbe ...kal sokale abar chalu hobe .... subhadip
# result : []
# line:
#  25/02/24, 10:27 pm - Saikat: IMG-20240225-WA0001.jpg (file attached)
# result : []
# line:
#  25/02/24, 10:27 pm - Saikat: IMG-20240225-WA0002.jpg (file attached)
# result : []
# line:
#  26/02/24, 12:36 am - +91 73195 35266: AJ sakale theke amar meal off thakbe (Amiya)
# result : []
# line:
#  26/02/24, 6:06 pm - +91 82509 91152: This message was deleted
# result : []
# line:
#  26/02/24, 6:15 pm - +91 82509 91152: IMG-20240226-WA0000.jpg (file attached)
# result : []
# line:
#  Sobai 2 tarik modha taka jama korba
# result : []
# line:
#  27/02/24, 2:34 pm - +91 76027 79174: Continue mil off tak be aj teke... Niru Mandi 🙏👍
# result : []
# line:
#  27/02/24, 5:37 pm - +91 832 874 4399: Aj rate meal off hobe ...kal sokal theke abar chalu hobe........ subhadip
# result : []

# %%
df = pd.DataFrame(parsedData, columns=['Date', 'Time', 'Author', 'Message']) # Initialising a pandas Dataframe.
df["Date"] = pd.to_datetime(df["Date"])
df.tail(20)
# Out:
#   Date  Time Author                                            Message
# 0  NaT  None   None  15/08/23, 10:52 am - Susovan (Mess: IMG-202308...

# %%
df.Author.unique()
# Out:
# array([None], dtype=object)

# %%
media_messages = df[df['Message'] == '<Media omitted>'].shape[0]
# print(media_messages)

def split_count(text):
    data = re.findall(r'\X', text)
    emoji_list = []

    for word in data:
      emojis = emoji.distinct_emoji_list(word)
      emoji_list.extend([emoji.demojize(is_emoji) for is_emoji in emojis])

    # emoji_list = []
    # for word in data:
    #   if any(char in emoji.distinct_emoji_list for char in word):
    #     emoji_list.append(word)
    return emoji_list

df["emoji"] = df["Message"].apply(split_count)
emojis = sum(df['emoji'].str.len())
# print(emojis)
URLPATTERN = r'(https?://\S+)'
df['urlcount'] = df.Message.apply(lambda x: re.findall(URLPATTERN, x)).str.len()
links = np.sum(df.urlcount)
# print("Data science Community")
# print("Messages:",total_messages)
print("Media:",media_messages)
print("Emojis:",emojis)
print("Links:",links)
# Out:
# Media: 0
# Emojis: 138
# Links: 2

# %%
media_messages_df = df[df['Message'] == '<Media omitted>']
messages_df = df.drop(media_messages_df.index)
messages_df.info()
messages_df['Letter_Count'] = messages_df['Message'].apply(lambda s : len(s))
messages_df['Word_Count'] = messages_df['Message'].apply(lambda s : len(s.split(' ')))
messages_df["MessageCount"]=1

l = ['a','b','c'] # list of the authors name in the group

for i in range(len(l)):
    # Filtering out messages of particular user
    req_df= messages_df[messages_df["Author"] == l[i]]
    # req_df will contain messages of only one particular user
    print('\n')
    print(f'Stats of {l[i]} -')
    # shape will print number of rows which indirectly means the number of messages
    print('Messages Sent', req_df.shape[0])
    #Word_Count contains of total words in one message. Sum of all words/ Total Messages will yield words per message
    words_per_message = (np.sum(req_df['Word_Count']))/req_df.shape[0]
    print('Words per message', words_per_message)
    #media conists of media messages
    media = media_messages_df[media_messages_df['Author'] == l[i]].shape[0]
    print('Media Messages Sent', media)
    # emojis conists of total emojis
    emojis = sum(req_df['emoji'].str.len())
    print('Emojis Sent', emojis)
    #links consist of total links
    links = sum(req_df["urlcount"])
    print('Links Sent', links)
    print('\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      0 non-null      datetime64[ns]
#  1   Time      0 non-null      object
#  2   Author    0 non-null      object
#  3   Message   1 non-null      object
#  4   emoji     1 non-null      object
#  5   urlcount  1 non-null      int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 176.0+ bytes
#
#
# Stats of a -
# Messages Sent 0
# Words per message nan
# Media Messages Sent 0
# Emojis Sent 0
# Links Sent 0
#
#
#
#
# Stats of b -
# Messages Sent 0
# Words per message nan
# Media Messages Sent 0
# Emojis Sent 0
# Links Sent 0
#
#
#
#
# Stats of c -
# Messages Sent 0
# Words per message nan
# Media Messages Sent 0
# Emojis Sent 0
# Links Sent 0
# C:\Users\tapas\AppData\Local\Temp\ipykernel_13912\4236246478.py:19: RuntimeWarning: invalid value encountered in longlong_scalars
#   words_per_message = (np.sum(req_df['Word_Count']))/req_df.shape[0]

# %%
total_emojis_list = list([a for b in messages_df.emoji for a in b])
emoji_dict = dict(Counter(total_emojis_list))
emoji_dict = sorted(emoji_dict.items(), key=lambda x: x[1], reverse=True)
for i in emoji_dict:
    print(i)
# Out:
# (':thumbs_up:', 61)
# (':folded_hands:', 32)
# (':mobile_phone_off:', 12)
# (':beaming_face_with_smiling_eyes:', 11)
# (':relieved_face:', 5)
# (':smiling_face_with_hearts:', 3)
# (':backhand_index_pointing_right:', 3)
# (':firecracker:', 2)
# (':face_holding_back_tears:', 1)
# (':winking_face:', 1)
# (':face_with_raised_eyebrow:', 1)
# (':face_blowing_a_kiss:', 1)
# (':red_heart:', 1)
# (':backhand_index_pointing_left:', 1)
# (':love-you_gesture:', 1)
# (':person_cartwheeling:', 1)
# (':grinning_face_with_big_eyes:', 1)

# %%
#Ploting the Wordcloud
text = " ".join(review for review in messages_df.Message)
print ("There are {} words in all the messages.".format(len(text)))
stopwords = set(STOPWORDS)
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# There are 45101 words in all the messages.

# %%
messages_df
# Out:
#   Date  Time Author                                            Message  \
# 0  NaT  None   None  15/08/23, 10:52 am - Susovan (Mess: IMG-202308...
#
#                                                emoji  urlcount  Letter_Count  \
# 0  [:folded_hands:, :thumbs_up:, :folded_hands:, ...         2         45101
#
#    Word_Count  MessageCount
# 0        7285             1
